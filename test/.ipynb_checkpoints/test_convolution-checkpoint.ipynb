# %%
import sys 
sys.path.append('..')
from projet_etu import *
import numpy as np 
import matplotlib as plt 
from mltools import *
from utils import *
import pickle as pkl
from loss import *
from activation import *
from sklearn.datasets import load_digits
import pandas as pd
from convolution import *

# %%
# Load data
data = pkl.load(open("../data/usps.pkl", "rb"))

X_train = np.array(data["X_train"], dtype=float).reshape(-1, 16 * 16, 1)
X_test = np.array(data["X_test"], dtype=float).reshape(-1, 16 * 16, 1)
# X_train = np.array(data["X_train"], dtype=float)
# X_test = np.array(data["X_test"], dtype=float)
# X_train = X_train[:, :, np.newaxis]
Y_train = data["Y_train"]
Y_test = data["Y_test"]
def one_hot(y):
    y_one_hot = np.zeros((y.shape[0], 10))
    y_one_hot[np.arange(y.shape[0]), y] = 1
    return y_one_hot


Y_train = one_hot(Y_train)
Y_test = one_hot(Y_test)

# %%
net = Sequential(
    [Conv1D(3, 1, 32),
    MaxPool1D(2, 2),
    Flatten(),
    Linear(4064, 100),
    ReLU(),
    Linear(100, 10)]
)
loss = CrossEntropyLoss()

# %%
Lerror, Lscore, Lerror_train, Lerror_test = SGD(net, loss, X_train, Y_train, predict= lambda x : np.argmax(net.forward(x),axis = 1), xtest = X_test, ytest = np.argmax(Y_test,axis =1), batch_size=10, max_iter=100, eps =0.001)
# Out:
# Epoch: 0 / 100
# Loss  0.683
# score  0.646
# Epoch: 1 / 100
# Loss  0.566
# score  0.783
# Epoch: 2 / 100
# Loss  0.5
# score  0.839
# Epoch: 3 / 100
# Loss  0.454
# score  0.863
# Epoch: 4 / 100
# Loss  0.42
# score  0.875
# Epoch: 5 / 100
# Loss  0.395
# score  0.881
# Epoch: 6 / 100
# Loss  0.379
# score  0.887
# Epoch: 7 / 100
# Loss  0.364
# score  0.891
# Epoch: 8 / 100
# Loss  0.353
# score  0.895
# Epoch: 9 / 100
# Loss  0.343
# score  0.899
# Epoch: 10 / 100
# Loss  0.333
# score  0.899
# Epoch: 11 / 100
# Loss  0.325
# score  0.9
# Epoch: 12 / 100
# Loss  0.32
# score  0.904
# Epoch: 13 / 100
# Loss  0.314
# score  0.904
# Epoch: 14 / 100
# Loss  0.308
# score  0.906
# Epoch: 15 / 100
# Loss  0.303
# score  0.908
# Epoch: 16 / 100
# Loss  0.299
# score  0.91
# Epoch: 17 / 100
# Loss  0.295
# score  0.912
# Epoch: 18 / 100
# Loss  0.29
# score  0.912
# Epoch: 19 / 100
# Loss  0.287
# score  0.914
# Epoch: 20 / 100
# Loss  0.287
# score  0.914
# Epoch: 21 / 100
# Loss  0.281
# score  0.914
# Epoch: 22 / 100
# Loss  0.278
# score  0.915
# Epoch: 23 / 100
# Loss  0.276
# score  0.917
# Epoch: 24 / 100
# Loss  0.273
# score  0.916
# Epoch: 25 / 100
# Loss  0.272
# score  0.917
# Epoch: 26 / 100
# Loss  0.272
# score  0.917
# Epoch: 27 / 100
# Loss  0.27
# score  0.917
# Epoch: 28 / 100
# Loss  0.267
# score  0.918
# Epoch: 29 / 100
# Loss  0.267
# score  0.918
# Epoch: 30 / 100
# Loss  0.264
# score  0.919
# Epoch: 31 / 100
# Loss  0.265
# score  0.919
# Epoch: 32 / 100
# Loss  0.264
# score  0.919
# Epoch: 33 / 100
# Loss  0.261
# score  0.919
# Epoch: 34 / 100
# Loss  0.262
# score  0.92
# Epoch: 35 / 100
# Loss  0.261
# score  0.919
# Epoch: 36 / 100
# Loss  0.261
# score  0.92
# Epoch: 37 / 100
# Loss  0.261
# score  0.92
# Epoch: 38 / 100
# Loss  0.259
# score  0.92
# Epoch: 39 / 100
# Loss  0.259
# score  0.92
# Epoch: 40 / 100
# Loss  0.259
# score  0.92
# Epoch: 41 / 100
# Loss  0.259
# score  0.921
# Epoch: 42 / 100
# Loss  0.258
# score  0.921
# Epoch: 43 / 100
# Loss  0.259
# score  0.921
# Epoch: 44 / 100
# Loss  0.261
# score  0.922
# Epoch: 45 / 100
# Loss  0.259
# score  0.922
# Epoch: 46 / 100
# Loss  0.258
# score  0.921
# Epoch: 47 / 100
# Loss  0.26
# score  0.924
# Epoch: 48 / 100
# Loss  0.258
# score  0.923
# Epoch: 49 / 100
# Loss  0.259
# score  0.923
# Epoch: 50 / 100
# Loss  0.257
# score  0.923
# Epoch: 51 / 100
# Loss  0.261
# score  0.924
# Epoch: 52 / 100
# Loss  0.26
# score  0.923
# Epoch: 53 / 100
# Loss  0.258
# score  0.922
# Epoch: 54 / 100
# Loss  0.258
# score  0.921
# Epoch: 55 / 100
# Loss  0.26
# score  0.924
# Epoch: 56 / 100
# Loss  0.259
# score  0.922
# Epoch: 57 / 100
# Loss  0.259
# score  0.924
# Epoch: 58 / 100
# Loss  0.259
# score  0.923
# Epoch: 59 / 100
# Loss  0.259
# score  0.922
# Epoch: 60 / 100
# Loss  0.259
# score  0.923
# Epoch: 61 / 100
# Loss  0.258
# score  0.921
# Epoch: 62 / 100
# Loss  0.259
# score  0.923
# Epoch: 63 / 100
# Loss  0.258
# score  0.923
# Epoch: 64 / 100
# Loss  0.262
# score  0.925
# Epoch: 65 / 100
# Loss  0.256
# score  0.923
# Epoch: 66 / 100
# Loss  0.26
# score  0.923
# Epoch: 67 / 100
# Loss  0.255
# score  0.922
# Epoch: 68 / 100
# Loss  0.259
# score  0.923
# Epoch: 69 / 100
# Loss  0.258
# score  0.923
# Epoch: 70 / 100
# Loss  0.259
# score  0.923
# Epoch: 71 / 100
# Loss  0.259
# score  0.924
# Epoch: 72 / 100
# Loss  0.258
# score  0.925
# Epoch: 73 / 100
# Loss  0.257
# score  0.924
# Epoch: 74 / 100
# Loss  0.256
# score  0.925
# Epoch: 75 / 100
# Loss  0.253
# score  0.924
# Epoch: 76 / 100
# Loss  0.252
# score  0.926
# Epoch: 77 / 100
# Loss  0.249
# score  0.925
# Epoch: 78 / 100
# Loss  0.249
# score  0.926
# Epoch: 79 / 100
# Loss  0.248
# score  0.926
# Epoch: 80 / 100
# Loss  0.247
# score  0.926
# Epoch: 81 / 100
# Loss  0.247
# score  0.926
# Epoch: 82 / 100
# Loss  0.241
# score  0.928
# Epoch: 83 / 100
# Loss  0.239
# score  0.927
# Epoch: 84 / 100
# Loss  0.237
# score  0.925
# Epoch: 85 / 100
# Loss  0.232
# score  0.926
# Epoch: 86 / 100
# Loss  0.233
# score  0.927
# Epoch: 87 / 100
# Loss  0.23
# score  0.927
# Epoch: 88 / 100
# Loss  0.229
# score  0.927
# Epoch: 89 / 100
# Loss  0.229
# score  0.926
# Epoch: 90 / 100
# Loss  0.222
# score  0.927
# Epoch: 91 / 100
# Loss  0.225
# score  0.928
# Epoch: 92 / 100
# Loss  0.219
# score  0.926
# Epoch: 93 / 100
# Loss  0.221
# score  0.928
# Epoch: 94 / 100
# Loss  0.213
# score  0.928
# Epoch: 95 / 100
# Loss  0.212
# score  0.928
# Epoch: 96 / 100
# Loss  0.208
# score  0.93
# Epoch: 97 / 100
# Loss  0.206
# score  0.928
# Epoch: 98 / 100
# Loss  0.207
# score  0.928
# Epoch: 99 / 100
# Loss  0.202
# score  0.929

# %%
plt.plot(Lerror,label =' loss')
plt.legend()
plt.show()

# %%
plt.plot(Lscore,label =' score_test')
plt.legend()
plt.show()

# %%
y_pred = np.argmax(net.forward(X_test),axis = 1)
y_true = np.argmax(Y_test,axis =1)
plot_confusion_matrix(net, X_test, y_true)

# %% [markdown]
# ## test conv1D avec plusieur couche de convolution

# %%
net = Sequential(
    [Conv1D(2,1, 6),
    MaxPool1D(2, 2),
    Conv1D(2, 6, 16),
    MaxPool1D(2, 2),
    Flatten(),
    Linear(1008, 120),
    ReLU(),
    Linear(120, 84),
    ReLU(),
    Linear(84, 10)]
)

loss = CrossEntropyLoss()
Lerror, Lscore= SGD(net, loss, X_train, Y_train, predict= lambda x : np.argmax(net.forward(x),axis = 1), xtest = X_test, ytest = np.argmax(Y_test,axis =1), batch_size=5, max_iter=100, eps =0.001)
# Out:
# Epoch: 0 / 100
# Loss  0.91
# score  0.16
# Epoch: 1 / 100
# Loss  0.878
# score  0.283
# Epoch: 2 / 100
# Loss  0.863
# score  0.33
# Epoch: 3 / 100
# Loss  0.85
# score  0.359
# Epoch: 4 / 100
# Loss  0.837
# score  0.372
# Epoch: 5 / 100
# Loss  0.824
# score  0.386
# Epoch: 6 / 100
# Loss  0.814
# score  0.405
# Epoch: 7 / 100
# Loss  0.804
# score  0.414
# Epoch: 8 / 100
# Loss  0.798
# score  0.432
# Epoch: 9 / 100
# Loss  0.793
# score  0.438
# Epoch: 10 / 100
# Loss  0.788
# score  0.435
# Epoch: 11 / 100
# Loss  0.776
# score  0.465
# Epoch: 12 / 100
# Loss  0.758
# score  0.502
# Epoch: 13 / 100
# Loss  0.733
# score  0.543
# Epoch: 14 / 100
# Loss  0.701
# score  0.587
# Epoch: 15 / 100
# Loss  0.67
# score  0.644
# Epoch: 16 / 100
# Loss  0.632
# score  0.688
# Epoch: 17 / 100
# Loss  0.598
# score  0.726
# Epoch: 18 / 100
# Loss  0.56
# score  0.763
# Epoch: 19 / 100
# Loss  0.526
# score  0.788
# Epoch: 20 / 100
# Loss  0.494
# score  0.81
# Epoch: 21 / 100
# Loss  0.469
# score  0.823
# Epoch: 22 / 100
# Loss  0.447
# score  0.841
# Epoch: 23 / 100
# Loss  0.428
# score  0.848
# Epoch: 24 / 100
# Loss  0.41
# score  0.85
# Epoch: 25 / 100
# Loss  0.399
# score  0.861
# Epoch: 26 / 100
# Loss  0.388
# score  0.866
# Epoch: 27 / 100
# Loss  0.379
# score  0.868
# Epoch: 28 / 100
# Loss  0.373
# score  0.876
# Epoch: 29 / 100
# Loss  0.363
# score  0.877
# Epoch: 30 / 100
# Loss  0.362
# score  0.879
# Epoch: 31 / 100
# Loss  0.356
# score  0.881
# Epoch: 32 / 100
# Loss  0.356
# score  0.88
# Epoch: 33 / 100
# Loss  0.354
# score  0.887
# Epoch: 34 / 100
# Loss  0.357
# score  0.884
# Epoch: 35 / 100
# Loss  0.365
# score  0.887
# Epoch: 36 / 100
# Loss  0.374
# score  0.888
# Epoch: 37 / 100
# Loss  0.389
# score  0.894
# Epoch: 38 / 100
# Loss  0.411
# score  0.882
# Epoch: 39 / 100
# Loss  0.45
# score  0.867
# Epoch: 40 / 100
# Loss  0.516
# score  0.836
# Epoch: 41 / 100
# Loss  0.613
# score  0.733
# Epoch: 42 / 100
# Loss  0.663
# score  0.612
# Epoch: 43 / 100
# Loss  0.604
# score  0.656
# Epoch: 44 / 100
# Loss  0.54
# score  0.727
# Epoch: 45 / 100
# Loss  0.487
# score  0.781
# Epoch: 46 / 100
# Loss  0.439
# score  0.816
# Epoch: 47 / 100
# Loss  0.406
# score  0.85
# Epoch: 48 / 100
# Loss  0.375
# score  0.867
# Epoch: 49 / 100
# Loss  0.349
# score  0.876
# Epoch: 50 / 100
# Loss  0.331
# score  0.884
# Epoch: 51 / 100
# Loss  0.314
# score  0.891
# Epoch: 52 / 100
# Loss  0.296
# score  0.898
# Epoch: 53 / 100
# Loss  0.285
# score  0.904
# Epoch: 54 / 100
# Loss  0.275
# score  0.907
# Epoch: 55 / 100
# Loss  0.266
# score  0.912
# Epoch: 56 / 100
# Loss  0.261
# score  0.913
# Epoch: 57 / 100
# Loss  0.253
# score  0.915
# Epoch: 58 / 100
# Loss  0.246
# score  0.915
# Epoch: 59 / 100
# Loss  0.242
# score  0.918
# Epoch: 60 / 100
# Loss  0.235
# score  0.92
# Epoch: 61 / 100
# Loss  0.234
# score  0.921
# Epoch: 62 / 100
# Loss  0.225
# score  0.922
# Epoch: 63 / 100
# Loss  0.22
# score  0.924
# Epoch: 64 / 100
# Loss  0.218
# score  0.923
# Epoch: 65 / 100
# Loss  0.214
# score  0.925
# Epoch: 66 / 100
# Loss  0.212
# score  0.927
# Epoch: 67 / 100
# Loss  0.21
# score  0.927
# Epoch: 68 / 100
# Loss  0.206
# score  0.929
# Epoch: 69 / 100
# Loss  0.204
# score  0.927
# Epoch: 70 / 100
# Loss  0.201
# score  0.931
# Epoch: 71 / 100
# Loss  0.201
# score  0.93
# Epoch: 72 / 100
# Loss  0.195
# score  0.93
# Epoch: 73 / 100
# Loss  0.195
# score  0.93
# Epoch: 74 / 100
# Loss  0.193
# score  0.933
# Epoch: 75 / 100
# Loss  0.19
# score  0.933
# Epoch: 76 / 100
# Loss  0.187
# score  0.933
# Epoch: 77 / 100
# Loss  0.185
# score  0.933
# Epoch: 78 / 100
# Loss  0.188
# score  0.935
# Epoch: 79 / 100
# Loss  0.18
# score  0.934
# Epoch: 80 / 100
# Loss  0.181
# score  0.935
# Epoch: 81 / 100
# Loss  0.18
# score  0.935
# Epoch: 82 / 100
# Loss  0.18
# score  0.937
# Epoch: 83 / 100
# Loss  0.178
# score  0.937
# Epoch: 84 / 100
# Loss  0.172
# score  0.936
# Epoch: 85 / 100
# Loss  0.174
# score  0.938
# Epoch: 86 / 100
# Loss  0.17
# score  0.939
# Epoch: 87 / 100
# Loss  0.169
# score  0.939
# Epoch: 88 / 100
# Loss  0.17
# score  0.938
# Epoch: 89 / 100
# Loss  0.167
# score  0.939
# Epoch: 90 / 100
# Loss  0.165
# score  0.94
# Epoch: 91 / 100
# Loss  0.168
# score  0.941
# Epoch: 92 / 100
# Loss  0.162
# score  0.94
# Epoch: 93 / 100
# Loss  0.162
# score  0.941
# Epoch: 94 / 100
# Loss  0.165
# score  0.943
# Epoch: 95 / 100
# Loss  0.16
# score  0.941
# Epoch: 96 / 100
# Loss  0.16
# score  0.942
# Epoch: 97 / 100
# Loss  0.162
# score  0.941
# Epoch: 98 / 100
# Loss  0.161
# score  0.942
# Epoch: 99 / 100
# Loss  0.16
# score  0.942

# %%
plt.plot(Lerror,label =' loss' )
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(Lscore,label ='score')
plt.grid
plt.legend()
plt.show()

# %% [markdown]
# ## auto encoder with conv

# %%
from sklearn.metrics import confusion_matrix



y_true = np.argmax(Y_test,axis =1)
plot_confusion_matrix(net, X_test, y_true)

# %% [markdown]
# # test with other data

# %%
X_train = pd.read_csv("../data/fashion-mnist_train.csv")
X_test = pd.read_csv("../data/fashion-mnist_test.csv")
X_train = X_train.values
X_test = X_test.values
# normalize data 
Y_train = X_train[:,0]
Y_test = X_test[:,0]
X_train = X_train[:,1:] / 256
X_test = X_test[:,1:] / 256

# reshape data
X_train = X_train.reshape(-1, 28*28, 1)
X_test = X_test.reshape(-1, 28*28, 1)

# %%
net = Sequential(
    [Conv1D(2,1, 6),
    MaxPool1D(2, 2),
    Conv1D(2, 6, 16),
    MaxPool1D(2, 2),
    Flatten(),
    Linear(1008, 120),
    ReLU(),
    Linear(120, 84),
    ReLU(),
    Linear(84, 10)]
)

loss = CrossEntropyLoss()
Lerror, Lscore= SGD(net, loss, X_train, Y_train, predict= lambda x : np.argmax(net.forward(x),axis = 1), xtest = X_test, ytest = np.argmax(Y_test,axis =1), batch_size=5, max_iter=100, eps =0.001)
