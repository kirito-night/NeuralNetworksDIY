# %% [markdown]
# # test de moldule lineare

# %%
import sys 
sys.path.append('..')
from projet_etu import *
import numpy as np 
import matplotlib as plt 
from mltools import *
from utils import *

# %%
Xl, y = gen_arti(epsilon=0.1)
print(Xl.shape, y.shape)
plt.figure()
plot_data(Xl,y)


## Visualisation de la fonction de coût en 2D
plt.figure()
plt.show()
# Out:
# (1000, 2) (1000, 1)

# %%
linear = Linear(2, 1)
mse = MSELoss()

# %%
# Boucle d'apprentissage
for i in range(1000):
    # Forward pass 
    y_pred = linear.forward(Xl)
    loss = mse.forward(y, y_pred)

    # Backward pass
    delta = mse.backward(y, y_pred)
    linear.backward_update_gradient(Xl, delta)

    # Mise à jour des paramètres
    linear.update_parameters()
    linear.zero_grad()

    # Affichage de la perte
    if i % 10 == 0:
        print(f"Étape {i}, perte : {loss.mean()}")
# Out:
# Étape 0, perte : 0.1764804166096441
# Étape 10, perte : 0.17188831554618522
# Étape 20, perte : 0.16749336678404764
# Étape 30, perte : 0.16328630274154865
# Étape 40, perte : 0.15925834543258408
# Étape 50, perte : 0.1554011769459413
# Étape 60, perte : 0.1517069119266464
# Étape 70, perte : 0.14816807191174725
# Étape 80, perte : 0.14477756138437706
# Étape 90, perte : 0.14152864542047158
# Étape 100, perte : 0.13841492881220582
# Étape 110, perte : 0.13543033656113884
# Étape 120, perte : 0.13256909564226854
# Étape 130, perte : 0.1298257179477632
# Étape 140, perte : 0.1271949843260987
# Étape 150, perte : 0.12467192963874901
# Étape 160, perte : 0.12225182876248189
# Étape 170, perte : 0.11993018347075855
# Étape 180, perte : 0.11770271013274808
# Étape 190, perte : 0.1155653281730919
# Étape 200, perte : 0.11351414923981097
# Étape 210, perte : 0.11154546703167555
# Étape 220, perte : 0.10965574773997741
# Étape 230, perte : 0.10784162106298192
# Étape 240, perte : 0.10609987175441633
# Étape 250, perte : 0.10442743167019007
# Étape 260, perte : 0.10282137228016336
# Étape 270, perte : 0.10127889761419746
# Étape 280, perte : 0.09979733761395244
# Étape 290, perte : 0.0983741418639578
# Étape 300, perte : 0.0970068736773841
# Étape 310, perte : 0.09569320451370115
# Étape 320, perte : 0.09443090870703054
# Étape 330, perte : 0.09321785848550178
# Étape 340, perte : 0.0920520192633062
# Étape 350, perte : 0.09093144518842582
# Étape 360, perte : 0.08985427493019926
# Étape 370, perte : 0.08881872769198312
# Étape 380, perte : 0.08782309943518225
# Étape 390, perte : 0.08686575930186148
# Étape 400, perte : 0.08594514622402064
# Étape 410, perte : 0.08505976570841972
# Étape 420, perte : 0.08420818678658841
# Étape 430, perte : 0.08338903912034368
# Étape 440, perte : 0.0826010102537817
# Étape 450, perte : 0.08184284300330438
# Étape 460, perte : 0.08111333297779147
# Étape 470, perte : 0.08041132622154286
# Étape 480, perte : 0.07973571697308861
# Étape 490, perte : 0.07908544553340746
# Étape 500, perte : 0.0784594962375036
# Étape 510, perte : 0.07785689552367317
# Étape 520, perte : 0.077276710095146
# Étape 530, perte : 0.07671804516911801
# Étape 540, perte : 0.0761800428084968
# Étape 550, perte : 0.07566188033196827
# Étape 560, perte : 0.07516276879825838
# Étape 570, perte : 0.07468195156071263
# Étape 580, perte : 0.0742187028885462
# Étape 590, perte : 0.07377232665133453
# Étape 600, perte : 0.07334215506351414
# Étape 610, perte : 0.07292754748585277
# Étape 620, perte : 0.07252788928102225
# Étape 630, perte : 0.07214259072057265
# Étape 640, perte : 0.07177108594075851
# Étape 650, perte : 0.07141283194481295
# Étape 660, perte : 0.0710673076493981
# Étape 670, perte : 0.07073401297308748
# Étape 680, perte : 0.07041246796485298
# Étape 690, perte : 0.07010221197063993
# Étape 700, perte : 0.06980280283621702
# Étape 710, perte : 0.0695138161445856
# Étape 720, perte : 0.0692348444863232
# Étape 730, perte : 0.06896549676132319
# Étape 740, perte : 0.06870539751047153
# Étape 750, perte : 0.0684541862758787
# Étape 760, perte : 0.06821151698835508
# Étape 770, perte : 0.06797705738088582
# Étape 780, perte : 0.06775048842692404
# Étape 790, perte : 0.0675315038023808
# Étape 800, perte : 0.06731980937024662
# Étape 810, perte : 0.06711512268683163
# Étape 820, perte : 0.06691717252866197
# Étape 830, perte : 0.06672569843911726
# Étape 840, perte : 0.0665404502939372
# Étape 850, perte : 0.06636118788476966
# Étape 860, perte : 0.06618768051997005
# Étape 870, perte : 0.06601970664190111
# Étape 880, perte : 0.06585705346001673
# Étape 890, perte : 0.06569951659904807
# Étape 900, perte : 0.06554689976164121
# Étape 910, perte : 0.06539901440482633
# Étape 920, perte : 0.0652556794297273
# Étape 930, perte : 0.0651167208839473
# Étape 940, perte : 0.06498197167609172
# Étape 950, perte : 0.06485127130191515
# Étape 960, perte : 0.06472446558160105
# Étape 970, perte : 0.06460140640770586
# Étape 980, perte : 0.06448195150331998
# Étape 990, perte : 0.06436596419001778

# %%
plot_frontiere(Xl, lambda x: np.sign(linear.forward(x)), step=100)
plot_data(Xl, y)

# %%
#use sklearn to generate data
from sklearn.datasets import make_regression
Xl, y, coef = make_regression(
    n_samples=100, n_features=1, noise=1, random_state=42, coef=True
)

y = y.reshape(-1, 1)
print(Xl.shape, y.shape)

plt.plot(Xl, y, 'o')
plt.show()
# Out:
# (100, 1) (100, 1)

# %%
linear = Linear(1, 1, biais=True)
mse = MSELoss()

# %%
# Boucle d'apprentissage
loss_list = []
for i in range(1000):
    # Forward pass 
    y_pred = linear.forward(Xl)
    loss = mse.forward(y, y_pred)

    # Backward pass
    delta = mse.backward(y, y_pred)
    linear.backward_update_gradient(Xl, delta)

    # Mise à jour des paramètres
    linear.update_parameters()
    linear.zero_grad()

    # Affichage de la perte
    loss_list.append(loss.mean())

# %%
plt.plot(loss_list)
plt.show()

# %%
plt.plot(Xl,y_pred)
plt.scatter(Xl,y)
plt.show()

# %%
#use sklearn to generate data
from sklearn.datasets import make_regression
Xl, y, coef = make_regression(
    n_samples=100, n_features=5, noise=10, random_state=42, coef=True
)


y = y.reshape(-1, 1)
print(Xl.shape, y.shape)

plt.plot(Xl, y, 'o')
plt.show()
# Out:
# (100, 5) (100, 1)

# %%
linear = Linear(5, 1, biais=True)
mse = MSELoss()

# %%
# Boucle d'apprentissage
loss_list = []
for i in range(1000):
    # Forward pass 
    y_pred = linear.forward(Xl)
    loss = mse.forward(y, y_pred)

    # Backward pass
    delta = mse.backward(y, y_pred)
    linear.backward_update_gradient(Xl, delta)

    # Mise à jour des paramètres
    linear.update_parameters()
    linear.zero_grad()

    # Affichage de la perte
    loss_list.append(loss.mean())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /users/nfs/Etu3/28600693/Documents/M1/ML/ML_project/test/../projet_etu.py in forward(self, X)
#      52         try :
# ---> 53             assert X.shape[1] == self._parameters.shape[0], f"Erreur de dimension, X.shape[1] = {X.shape[1]} et self._parameters.shape[0] = {self._parameters.shape[0]}"
#      54             return X @ self._parameters
#
# AssertionError: Erreur de dimension, X.shape[1] = 6 et self._parameters.shape[0] = 2
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_191361/3326358274.py in <cell line: 3>()
#       3 for i in range(1000):
#       4     # Forward pass
# ----> 5     y_pred = linear.forward(Xl)
#       6     loss = mse.forward(y, y_pred)
#       7
#
# /users/nfs/Etu3/28600693/Documents/M1/ML/ML_project/test/../projet_etu.py in forward(self, X)
#      54             return X @ self._parameters
#      55         except AssertionError:
# ---> 56             raise AssertionError
#      57
#      58     def backward_update_gradient(self, input, delta):
#
# AssertionError:

# %%
plt.plot(loss_list)

# %%
plt.plot(Xl,y_pred)
plt.scatter(Xl,y)
plt.show()
