# %%
import sys 
sys.path.append('..')
from projet_etu import *
import numpy as np 
import matplotlib as plt 
from mltools import *
from utils import *

# %%
input_size = 2
hidden_size =16
output_size = 1
# Définir les données d'entraînement
X, Y = gen_arti(data_type=1)
Y = np.where(Y == -1, 0, Y)

# %%
linear1 = Linear(input_size, hidden_size)

tanh = TanH()
linear2 = Linear(hidden_size, output_size)
sigmoid = Sigmoid()
mse_loss = MSELoss()
ce_loss = CrossEntropyLoss()
loss_list = []

# %%
seq = Sequential([linear1, tanh, linear2, sigmoid])

# %%
Lerror, Lscore = SGD(seq, mse_loss, X, Y, predict= lambda x : np.round(seq.forward(x), 0).astype(int), eps=3e-3, max_iter= 1000, batch_size= 10)
# Out:
# Epoch: 0 / 1000
# cost  0.444
# score  0.54
#
# Epoch: 1 / 1000
# cost  0.441
# score  0.545
#
# Epoch: 2 / 1000
# cost  0.438
# score  0.555
#
# Epoch: 3 / 1000
# cost  0.435
# score  0.555
#
# Epoch: 4 / 1000
# cost  0.432
# score  0.555
#
# Epoch: 5 / 1000
# cost  0.429
# score  0.555
#
# Epoch: 6 / 1000
# cost  0.426
# score  0.555
#
# Epoch: 7 / 1000
# cost  0.423
# score  0.555
#
# Epoch: 8 / 1000
# cost  0.42
# score  0.565
#
# Epoch: 9 / 1000
# cost  0.417
# score  0.57
#
# Epoch: 10 / 1000
# cost  0.415
# score  0.57
#
# Epoch: 11 / 1000
# cost  0.412
# score  0.575
#
# Epoch: 12 / 1000
# cost  0.409
# score  0.59
#
# Epoch: 13 / 1000
# cost  0.406
# score  0.59
#
# Epoch: 14 / 1000
# cost  0.403
# score  0.6
#
# Epoch: 15 / 1000
# cost  0.4
# score  0.605
#
# Epoch: 16 / 1000
# cost  0.398
# score  0.605
#
# Epoch: 17 / 1000
# cost  0.395
# score  0.615
#
# Epoch: 18 / 1000
# cost  0.392
# score  0.615
#
# Epoch: 19 / 1000
# cost  0.389
# score  0.615
#
# Epoch: 20 / 1000
# cost  0.387
# score  0.63
#
# Epoch: 21 / 1000
# cost  0.384
# score  0.63
#
# Epoch: 22 / 1000
# cost  0.381
# score  0.64
#
# Epoch: 23 / 1000
# cost  0.379
# score  0.64
#
# Epoch: 24 / 1000
# cost  0.376
# score  0.645
#
# Epoch: 25 / 1000
# cost  0.374
# score  0.645
#
# Epoch: 26 / 1000
# cost  0.371
# score  0.655
#
# Epoch: 27 / 1000
# cost  0.369
# score  0.655
#
# Epoch: 28 / 1000
# cost  0.366
# score  0.66
#
# Epoch: 29 / 1000
# cost  0.364
# score  0.66
#
# Epoch: 30 / 1000
# cost  0.361
# score  0.66
#
# Epoch: 31 / 1000
# cost  0.359
# score  0.66
#
# Epoch: 32 / 1000
# cost  0.357
# score  0.66
#
# Epoch: 33 / 1000
# cost  0.355
# score  0.66
#
# Epoch: 34 / 1000
# cost  0.353
# score  0.66
#
# Epoch: 35 / 1000
# cost  0.35
# score  0.665
#
# Epoch: 36 / 1000
# cost  0.348
# score  0.67
#
# Epoch: 37 / 1000
# cost  0.346
# score  0.67
#
# Epoch: 38 / 1000
# cost  0.344
# score  0.67
#
# Epoch: 39 / 1000
# cost  0.342
# score  0.68
#
# Epoch: 40 / 1000
# cost  0.34
# score  0.685
#
# Epoch: 41 / 1000
# cost  0.339
# score  0.69
#
# Epoch: 42 / 1000
# cost  0.337
# score  0.69
#
# Epoch: 43 / 1000
# cost  0.335
# score  0.69
#
# Epoch: 44 / 1000
# cost  0.333
# score  0.69
#
# Epoch: 45 / 1000
# cost  0.332
# score  0.695
#
# Epoch: 46 / 1000
# cost  0.33
# score  0.695
#
# Epoch: 47 / 1000
# cost  0.328
# score  0.695
#
# Epoch: 48 / 1000
# cost  0.327
# score  0.695
#
# Epoch: 49 / 1000
# cost  0.325
# score  0.695
#
# Epoch: 50 / 1000
# cost  0.324
# score  0.695
#
# Epoch: 51 / 1000
# cost  0.322
# score  0.695
#
# Epoch: 52 / 1000
# cost  0.321
# score  0.7
#
# Epoch: 53 / 1000
# cost  0.32
# score  0.7
#
# Epoch: 54 / 1000
# cost  0.318
# score  0.7
#
# Epoch: 55 / 1000
# cost  0.317
# score  0.7
#
# Epoch: 56 / 1000
# cost  0.316
# score  0.7
#
# Epoch: 57 / 1000
# cost  0.314
# score  0.705
#
# Epoch: 58 / 1000
# cost  0.313
# score  0.71
#
# Epoch: 59 / 1000
# cost  0.312
# score  0.71
#
# Epoch: 60 / 1000
# cost  0.311
# score  0.71
#
# Epoch: 61 / 1000
# cost  0.31
# score  0.71
#
# Epoch: 62 / 1000
# cost  0.309
# score  0.71
#
# Epoch: 63 / 1000
# cost  0.307
# score  0.715
#
# Epoch: 64 / 1000
# cost  0.306
# score  0.715
#
# Epoch: 65 / 1000
# cost  0.305
# score  0.72
#
# Epoch: 66 / 1000
# cost  0.304
# score  0.72
#
# Epoch: 67 / 1000
# cost  0.303
# score  0.72
#
# Epoch: 68 / 1000
# cost  0.302
# score  0.72
#
# Epoch: 69 / 1000
# cost  0.301
# score  0.72
#
# Epoch: 70 / 1000
# cost  0.3
# score  0.72
#
# Epoch: 71 / 1000
# cost  0.3
# score  0.725
#
# Epoch: 72 / 1000
# cost  0.299
# score  0.725
#
# Epoch: 73 / 1000
# cost  0.298
# score  0.725
#
# Epoch: 74 / 1000
# cost  0.297
# score  0.73
#
# Epoch: 75 / 1000
# cost  0.296
# score  0.73
#
# Epoch: 76 / 1000
# cost  0.295
# score  0.73
#
# Epoch: 77 / 1000
# cost  0.295
# score  0.74
#
# Epoch: 78 / 1000
# cost  0.294
# score  0.74
#
# Epoch: 79 / 1000
# cost  0.293
# score  0.74
#
# Epoch: 80 / 1000
# cost  0.292
# score  0.745
#
# Epoch: 81 / 1000
# cost  0.292
# score  0.745
#
# Epoch: 82 / 1000
# cost  0.291
# score  0.745
#
# Epoch: 83 / 1000
# cost  0.29
# score  0.745
#
# Epoch: 84 / 1000
# cost  0.29
# score  0.745
#
# Epoch: 85 / 1000
# cost  0.289
# score  0.745
#
# Epoch: 86 / 1000
# cost  0.288
# score  0.745
#
# Epoch: 87 / 1000
# cost  0.288
# score  0.745
#
# Epoch: 88 / 1000
# cost  0.287
# score  0.745
#
# Epoch: 89 / 1000
# cost  0.286
# score  0.75
#
# Epoch: 90 / 1000
# cost  0.286
# score  0.755
#
# Epoch: 91 / 1000
# cost  0.285
# score  0.755
#
# Epoch: 92 / 1000
# cost  0.285
# score  0.755
#
# Epoch: 93 / 1000
# cost  0.284
# score  0.755
#
# Epoch: 94 / 1000
# cost  0.284
# score  0.76
#
# Epoch: 95 / 1000
# cost  0.283
# score  0.76
#
# Epoch: 96 / 1000
# cost  0.282
# score  0.76
#
# Epoch: 97 / 1000
# cost  0.282
# score  0.76
#
# Epoch: 98 / 1000
# cost  0.281
# score  0.76
#
# Epoch: 99 / 1000
# cost  0.281
# score  0.76
#
# Epoch: 100 / 1000
# cost  0.28
# score  0.76
#
# Epoch: 101 / 1000
# cost  0.28
# score  0.76
#
# Epoch: 102 / 1000
# cost  0.28
# score  0.765
#
# Epoch: 103 / 1000
# cost  0.279
# score  0.765
#
# Epoch: 104 / 1000
# cost  0.279
# score  0.765
#
# Epoch: 105 / 1000
# cost  0.278
# score  0.765
#
# Epoch: 106 / 1000
# cost  0.278
# score  0.77
#
# Epoch: 107 / 1000
# cost  0.277
# score  0.775
#
# Epoch: 108 / 1000
# cost  0.277
# score  0.775
#
# Epoch: 109 / 1000
# cost  0.277
# score  0.775
#
# Epoch: 110 / 1000
# cost  0.276
# score  0.775
#
# Epoch: 111 / 1000
# cost  0.276
# score  0.775
#
# Epoch: 112 / 1000
# cost  0.275
# score  0.775
#
# Epoch: 113 / 1000
# cost  0.275
# score  0.775
#
# Epoch: 114 / 1000
# cost  0.275
# score  0.775
#
# Epoch: 115 / 1000
# cost  0.274
# score  0.775
#
# Epoch: 116 / 1000
# cost  0.274
# score  0.775
#
# Epoch: 117 / 1000
# cost  0.274
# score  0.775
#
# Epoch: 118 / 1000
# cost  0.273
# score  0.775
#
# Epoch: 119 / 1000
# cost  0.273
# score  0.775
#
# Epoch: 120 / 1000
# cost  0.273
# score  0.775
#
# Epoch: 121 / 1000
# cost  0.272
# score  0.775
#
# Epoch: 122 / 1000
# cost  0.272
# score  0.775
#
# Epoch: 123 / 1000
# cost  0.272
# score  0.775
#
# Epoch: 124 / 1000
# cost  0.272
# score  0.775
#
# Epoch: 125 / 1000
# cost  0.271
# score  0.775
#
# Epoch: 126 / 1000
# cost  0.271
# score  0.775
#
# Epoch: 127 / 1000
# cost  0.271
# score  0.775
#
# Epoch: 128 / 1000
# cost  0.27
# score  0.775
#
# Epoch: 129 / 1000
# cost  0.27
# score  0.775
#
# Epoch: 130 / 1000
# cost  0.27
# score  0.775
#
# Epoch: 131 / 1000
# cost  0.27
# score  0.775
#
# Epoch: 132 / 1000
# cost  0.269
# score  0.775
#
# Epoch: 133 / 1000
# cost  0.269
# score  0.78
#
# Epoch: 134 / 1000
# cost  0.269
# score  0.78
#
# Epoch: 135 / 1000
# cost  0.269
# score  0.78
#
# Epoch: 136 / 1000
# cost  0.269
# score  0.78
#
# Epoch: 137 / 1000
# cost  0.268
# score  0.78
#
# Epoch: 138 / 1000
# cost  0.268
# score  0.78
#
# Epoch: 139 / 1000
# cost  0.268
# score  0.78
#
# Epoch: 140 / 1000
# cost  0.268
# score  0.78
#
# Epoch: 141 / 1000
# cost  0.267
# score  0.78
#
# Epoch: 142 / 1000
# cost  0.267
# score  0.78
#
# Epoch: 143 / 1000
# cost  0.267
# score  0.78
#
# Epoch: 144 / 1000
# cost  0.267
# score  0.78
#
# Epoch: 145 / 1000
# cost  0.267
# score  0.78
#
# Epoch: 146 / 1000
# cost  0.267
# score  0.78
#
# Epoch: 147 / 1000
# cost  0.266
# score  0.78
#
# Epoch: 148 / 1000
# cost  0.266
# score  0.78
#
# Epoch: 149 / 1000
# cost  0.266
# score  0.78
#
# Epoch: 150 / 1000
# cost  0.266
# score  0.78
#
# Epoch: 151 / 1000
# cost  0.266
# score  0.78
#
# Epoch: 152 / 1000
# cost  0.265
# score  0.78
#
# Epoch: 153 / 1000
# cost  0.265
# score  0.78
#
# Epoch: 154 / 1000
# cost  0.265
# score  0.78
#
# Epoch: 155 / 1000
# cost  0.265
# score  0.785
#
# Epoch: 156 / 1000
# cost  0.265
# score  0.785
#
# Epoch: 157 / 1000
# cost  0.265
# score  0.785
#
# Epoch: 158 / 1000
# cost  0.265
# score  0.79
#
# Epoch: 159 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 160 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 161 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 162 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 163 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 164 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 165 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 166 / 1000
# cost  0.264
# score  0.79
#
# Epoch: 167 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 168 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 169 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 170 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 171 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 172 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 173 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 174 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 175 / 1000
# cost  0.263
# score  0.79
#
# Epoch: 176 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 177 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 178 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 179 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 180 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 181 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 182 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 183 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 184 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 185 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 186 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 187 / 1000
# cost  0.262
# score  0.79
#
# Epoch: 188 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 189 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 190 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 191 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 192 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 193 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 194 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 195 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 196 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 197 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 198 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 199 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 200 / 1000
# cost  0.261
# score  0.79
#
# Epoch: 201 / 1000
# cost  0.261
# score  0.795
#
# Epoch: 202 / 1000
# cost  0.261
# score  0.795
#
# Epoch: 203 / 1000
# cost  0.261
# score  0.795
#
# Epoch: 204 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 205 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 206 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 207 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 208 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 209 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 210 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 211 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 212 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 213 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 214 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 215 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 216 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 217 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 218 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 219 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 220 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 221 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 222 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 223 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 224 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 225 / 1000
# cost  0.26
# score  0.795
#
# Epoch: 226 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 227 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 228 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 229 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 230 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 231 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 232 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 233 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 234 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 235 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 236 / 1000
# cost  0.259
# score  0.795
#
# Epoch: 237 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 238 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 239 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 240 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 241 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 242 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 243 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 244 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 245 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 246 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 247 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 248 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 249 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 250 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 251 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 252 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 253 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 254 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 255 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 256 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 257 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 258 / 1000
# cost  0.259
# score  0.8
#
# Epoch: 259 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 260 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 261 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 262 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 263 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 264 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 265 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 266 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 267 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 268 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 269 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 270 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 271 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 272 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 273 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 274 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 275 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 276 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 277 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 278 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 279 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 280 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 281 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 282 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 283 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 284 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 285 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 286 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 287 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 288 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 289 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 290 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 291 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 292 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 293 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 294 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 295 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 296 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 297 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 298 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 299 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 300 / 1000
# cost  0.258
# score  0.8
#
# Epoch: 301 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 302 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 303 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 304 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 305 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 306 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 307 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 308 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 309 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 310 / 1000
# cost  0.258
# score  0.805
#
# Epoch: 311 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 312 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 313 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 314 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 315 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 316 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 317 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 318 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 319 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 320 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 321 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 322 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 323 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 324 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 325 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 326 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 327 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 328 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 329 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 330 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 331 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 332 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 333 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 334 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 335 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 336 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 337 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 338 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 339 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 340 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 341 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 342 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 343 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 344 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 345 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 346 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 347 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 348 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 349 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 350 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 351 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 352 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 353 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 354 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 355 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 356 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 357 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 358 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 359 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 360 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 361 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 362 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 363 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 364 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 365 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 366 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 367 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 368 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 369 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 370 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 371 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 372 / 1000
# cost  0.257
# score  0.805
#
# Epoch: 373 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 374 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 375 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 376 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 377 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 378 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 379 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 380 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 381 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 382 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 383 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 384 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 385 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 386 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 387 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 388 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 389 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 390 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 391 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 392 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 393 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 394 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 395 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 396 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 397 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 398 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 399 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 400 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 401 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 402 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 403 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 404 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 405 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 406 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 407 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 408 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 409 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 410 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 411 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 412 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 413 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 414 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 415 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 416 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 417 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 418 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 419 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 420 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 421 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 422 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 423 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 424 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 425 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 426 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 427 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 428 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 429 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 430 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 431 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 432 / 1000
# cost  0.256
# score  0.805
#
# Epoch: 433 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 434 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 435 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 436 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 437 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 438 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 439 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 440 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 441 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 442 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 443 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 444 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 445 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 446 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 447 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 448 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 449 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 450 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 451 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 452 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 453 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 454 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 455 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 456 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 457 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 458 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 459 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 460 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 461 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 462 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 463 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 464 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 465 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 466 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 467 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 468 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 469 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 470 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 471 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 472 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 473 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 474 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 475 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 476 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 477 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 478 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 479 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 480 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 481 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 482 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 483 / 1000
# cost  0.255
# score  0.805
#
# Epoch: 484 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 485 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 486 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 487 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 488 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 489 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 490 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 491 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 492 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 493 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 494 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 495 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 496 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 497 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 498 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 499 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 500 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 501 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 502 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 503 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 504 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 505 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 506 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 507 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 508 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 509 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 510 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 511 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 512 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 513 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 514 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 515 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 516 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 517 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 518 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 519 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 520 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 521 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 522 / 1000
# cost  0.254
# score  0.805
#
# Epoch: 523 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 524 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 525 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 526 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 527 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 528 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 529 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 530 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 531 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 532 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 533 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 534 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 535 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 536 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 537 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 538 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 539 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 540 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 541 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 542 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 543 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 544 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 545 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 546 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 547 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 548 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 549 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 550 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 551 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 552 / 1000
# cost  0.253
# score  0.805
#
# Epoch: 553 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 554 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 555 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 556 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 557 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 558 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 559 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 560 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 561 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 562 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 563 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 564 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 565 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 566 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 567 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 568 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 569 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 570 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 571 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 572 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 573 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 574 / 1000
# cost  0.252
# score  0.805
#
# Epoch: 575 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 576 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 577 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 578 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 579 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 580 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 581 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 582 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 583 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 584 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 585 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 586 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 587 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 588 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 589 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 590 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 591 / 1000
# cost  0.251
# score  0.805
#
# Epoch: 592 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 593 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 594 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 595 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 596 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 597 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 598 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 599 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 600 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 601 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 602 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 603 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 604 / 1000
# cost  0.25
# score  0.805
#
# Epoch: 605 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 606 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 607 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 608 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 609 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 610 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 611 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 612 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 613 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 614 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 615 / 1000
# cost  0.249
# score  0.805
#
# Epoch: 616 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 617 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 618 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 619 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 620 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 621 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 622 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 623 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 624 / 1000
# cost  0.248
# score  0.805
#
# Epoch: 625 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 626 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 627 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 628 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 629 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 630 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 631 / 1000
# cost  0.247
# score  0.805
#
# Epoch: 632 / 1000
# cost  0.246
# score  0.805
#
# Epoch: 633 / 1000
# cost  0.246
# score  0.805
#
# Epoch: 634 / 1000
# cost  0.246
# score  0.805
#
# Epoch: 635 / 1000
# cost  0.246
# score  0.805
#
# Epoch: 636 / 1000
# cost  0.246
# score  0.805
#
# Epoch: 637 / 1000
# cost  0.246
# score  0.805
#
# Epoch: 638 / 1000
# cost  0.245
# score  0.805
#
# Epoch: 639 / 1000
# cost  0.245
# score  0.805
#
# Epoch: 640 / 1000
# cost  0.245
# score  0.805
#
# Epoch: 641 / 1000
# cost  0.245
# score  0.805
#
# Epoch: 642 / 1000
# cost  0.245
# score  0.805
#
# Epoch: 643 / 1000
# cost  0.245
# score  0.805
#
# Epoch: 644 / 1000
# cost  0.244
# score  0.805
#
# Epoch: 645 / 1000
# cost  0.244
# score  0.805
#
# Epoch: 646 / 1000
# cost  0.244
# score  0.805
#
# Epoch: 647 / 1000
# cost  0.244
# score  0.805
#
# Epoch: 648 / 1000
# cost  0.244
# score  0.805
#
# Epoch: 649 / 1000
# cost  0.243
# score  0.805
#
# Epoch: 650 / 1000
# cost  0.243
# score  0.805
#
# Epoch: 651 / 1000
# cost  0.243
# score  0.805
#
# Epoch: 652 / 1000
# cost  0.243
# score  0.805
#
# Epoch: 653 / 1000
# cost  0.242
# score  0.805
#
# Epoch: 654 / 1000
# cost  0.242
# score  0.805
#
# Epoch: 655 / 1000
# cost  0.242
# score  0.805
#
# Epoch: 656 / 1000
# cost  0.241
# score  0.805
#
# Epoch: 657 / 1000
# cost  0.241
# score  0.805
#
# Epoch: 658 / 1000
# cost  0.241
# score  0.805
#
# Epoch: 659 / 1000
# cost  0.241
# score  0.805
#
# Epoch: 660 / 1000
# cost  0.24
# score  0.805
#
# Epoch: 661 / 1000
# cost  0.24
# score  0.805
#
# Epoch: 662 / 1000
# cost  0.24
# score  0.805
#
# Epoch: 663 / 1000
# cost  0.239
# score  0.805
#
# Epoch: 664 / 1000
# cost  0.239
# score  0.805
#
# Epoch: 665 / 1000
# cost  0.238
# score  0.805
#
# Epoch: 666 / 1000
# cost  0.238
# score  0.805
#
# Epoch: 667 / 1000
# cost  0.238
# score  0.805
#
# Epoch: 668 / 1000
# cost  0.237
# score  0.805
#
# Epoch: 669 / 1000
# cost  0.237
# score  0.805
#
# Epoch: 670 / 1000
# cost  0.236
# score  0.805
#
# Epoch: 671 / 1000
# cost  0.236
# score  0.805
#
# Epoch: 672 / 1000
# cost  0.235
# score  0.805
#
# Epoch: 673 / 1000
# cost  0.235
# score  0.805
#
# Epoch: 674 / 1000
# cost  0.234
# score  0.805
#
# Epoch: 675 / 1000
# cost  0.234
# score  0.805
#
# Epoch: 676 / 1000
# cost  0.233
# score  0.805
#
# Epoch: 677 / 1000
# cost  0.232
# score  0.805
#
# Epoch: 678 / 1000
# cost  0.232
# score  0.8
#
# Epoch: 679 / 1000
# cost  0.231
# score  0.8
#
# Epoch: 680 / 1000
# cost  0.23
# score  0.8
#
# Epoch: 681 / 1000
# cost  0.23
# score  0.8
#
# Epoch: 682 / 1000
# cost  0.229
# score  0.8
#
# Epoch: 683 / 1000
# cost  0.228
# score  0.8
#
# Epoch: 684 / 1000
# cost  0.227
# score  0.8
#
# Epoch: 685 / 1000
# cost  0.226
# score  0.8
#
# Epoch: 686 / 1000
# cost  0.225
# score  0.8
#
# Epoch: 687 / 1000
# cost  0.225
# score  0.8
#
# Epoch: 688 / 1000
# cost  0.224
# score  0.8
#
# Epoch: 689 / 1000
# cost  0.222
# score  0.8
#
# Epoch: 690 / 1000
# cost  0.221
# score  0.8
#
# Epoch: 691 / 1000
# cost  0.22
# score  0.8
#
# Epoch: 692 / 1000
# cost  0.219
# score  0.8
#
# Epoch: 693 / 1000
# cost  0.218
# score  0.8
#
# Epoch: 694 / 1000
# cost  0.216
# score  0.8
#
# Epoch: 695 / 1000
# cost  0.215
# score  0.8
#
# Epoch: 696 / 1000
# cost  0.213
# score  0.8
#
# Epoch: 697 / 1000
# cost  0.212
# score  0.8
#
# Epoch: 698 / 1000
# cost  0.21
# score  0.8
#
# Epoch: 699 / 1000
# cost  0.209
# score  0.8
#
# Epoch: 700 / 1000
# cost  0.207
# score  0.8
#
# Epoch: 701 / 1000
# cost  0.205
# score  0.8
#
# Epoch: 702 / 1000
# cost  0.203
# score  0.8
#
# Epoch: 703 / 1000
# cost  0.201
# score  0.8
#
# Epoch: 704 / 1000
# cost  0.199
# score  0.8
#
# Epoch: 705 / 1000
# cost  0.197
# score  0.8
#
# Epoch: 706 / 1000
# cost  0.194
# score  0.8
#
# Epoch: 707 / 1000
# cost  0.192
# score  0.8
#
# Epoch: 708 / 1000
# cost  0.189
# score  0.8
#
# Epoch: 709 / 1000
# cost  0.187
# score  0.8
#
# Epoch: 710 / 1000
# cost  0.184
# score  0.8
#
# Epoch: 711 / 1000
# cost  0.181
# score  0.8
#
# Epoch: 712 / 1000
# cost  0.179
# score  0.8
#
# Epoch: 713 / 1000
# cost  0.176
# score  0.8
#
# Epoch: 714 / 1000
# cost  0.173
# score  0.8
#
# Epoch: 715 / 1000
# cost  0.17
# score  0.8
#
# Epoch: 716 / 1000
# cost  0.167
# score  0.8
#
# Epoch: 717 / 1000
# cost  0.164
# score  0.8
#
# Epoch: 718 / 1000
# cost  0.162
# score  0.8
#
# Epoch: 719 / 1000
# cost  0.159
# score  0.8
#
# Epoch: 720 / 1000
# cost  0.156
# score  0.8
#
# Epoch: 721 / 1000
# cost  0.153
# score  0.8
#
# Epoch: 722 / 1000
# cost  0.151
# score  0.8
#
# Epoch: 723 / 1000
# cost  0.148
# score  0.8
#
# Epoch: 724 / 1000
# cost  0.146
# score  0.8
#
# Epoch: 725 / 1000
# cost  0.143
# score  0.8
#
# Epoch: 726 / 1000
# cost  0.141
# score  0.8
#
# Epoch: 727 / 1000
# cost  0.139
# score  0.8
#
# Epoch: 728 / 1000
# cost  0.137
# score  0.8
#
# Epoch: 729 / 1000
# cost  0.135
# score  0.8
#
# Epoch: 730 / 1000
# cost  0.133
# score  0.81
#
# Epoch: 731 / 1000
# cost  0.131
# score  0.825
#
# Epoch: 732 / 1000
# cost  0.129
# score  0.85
#
# Epoch: 733 / 1000
# cost  0.128
# score  0.865
#
# Epoch: 734 / 1000
# cost  0.126
# score  0.885
#
# Epoch: 735 / 1000
# cost  0.125
# score  0.905
#
# Epoch: 736 / 1000
# cost  0.123
# score  0.91
#
# Epoch: 737 / 1000
# cost  0.122
# score  0.935
#
# Epoch: 738 / 1000
# cost  0.121
# score  0.95
#
# Epoch: 739 / 1000
# cost  0.12
# score  0.96
#
# Epoch: 740 / 1000
# cost  0.119
# score  0.96
#
# Epoch: 741 / 1000
# cost  0.118
# score  0.965
#
# Epoch: 742 / 1000
# cost  0.117
# score  0.965
#
# Epoch: 743 / 1000
# cost  0.116
# score  0.965
#
# Epoch: 744 / 1000
# cost  0.115
# score  0.97
#
# Epoch: 745 / 1000
# cost  0.114
# score  0.97
#
# Epoch: 746 / 1000
# cost  0.113
# score  0.97
#
# Epoch: 747 / 1000
# cost  0.112
# score  0.97
#
# Epoch: 748 / 1000
# cost  0.111
# score  0.97
#
# Epoch: 749 / 1000
# cost  0.11
# score  0.97
#
# Epoch: 750 / 1000
# cost  0.11
# score  0.97
#
# Epoch: 751 / 1000
# cost  0.109
# score  0.97
#
# Epoch: 752 / 1000
# cost  0.108
# score  0.97
#
# Epoch: 753 / 1000
# cost  0.107
# score  0.97
#
# Epoch: 754 / 1000
# cost  0.107
# score  0.97
#
# Epoch: 755 / 1000
# cost  0.106
# score  0.97
#
# Epoch: 756 / 1000
# cost  0.105
# score  0.97
#
# Epoch: 757 / 1000
# cost  0.105
# score  0.97
#
# Epoch: 758 / 1000
# cost  0.104
# score  0.97
#
# Epoch: 759 / 1000
# cost  0.103
# score  0.97
#
# Epoch: 760 / 1000
# cost  0.103
# score  0.97
#
# Epoch: 761 / 1000
# cost  0.102
# score  0.97
#
# Epoch: 762 / 1000
# cost  0.101
# score  0.97
#
# Epoch: 763 / 1000
# cost  0.101
# score  0.97
#
# Epoch: 764 / 1000
# cost  0.1
# score  0.97
#
# Epoch: 765 / 1000
# cost  0.1
# score  0.97
#
# Epoch: 766 / 1000
# cost  0.099
# score  0.97
#
# Epoch: 767 / 1000
# cost  0.098
# score  0.97
#
# Epoch: 768 / 1000
# cost  0.098
# score  0.97
#
# Epoch: 769 / 1000
# cost  0.097
# score  0.97
#
# Epoch: 770 / 1000
# cost  0.097
# score  0.97
#
# Epoch: 771 / 1000
# cost  0.096
# score  0.97
#
# Epoch: 772 / 1000
# cost  0.095
# score  0.97
#
# Epoch: 773 / 1000
# cost  0.095
# score  0.97
#
# Epoch: 774 / 1000
# cost  0.094
# score  0.97
#
# Epoch: 775 / 1000
# cost  0.094
# score  0.97
#
# Epoch: 776 / 1000
# cost  0.093
# score  0.975
#
# Epoch: 777 / 1000
# cost  0.093
# score  0.975
#
# Epoch: 778 / 1000
# cost  0.092
# score  0.98
#
# Epoch: 779 / 1000
# cost  0.092
# score  0.98
#
# Epoch: 780 / 1000
# cost  0.091
# score  0.98
#
# Epoch: 781 / 1000
# cost  0.091
# score  0.98
#
# Epoch: 782 / 1000
# cost  0.09
# score  0.98
#
# Epoch: 783 / 1000
# cost  0.09
# score  0.985
#
# Epoch: 784 / 1000
# cost  0.089
# score  0.985
#
# Epoch: 785 / 1000
# cost  0.089
# score  0.985
#
# Epoch: 786 / 1000
# cost  0.088
# score  0.985
#
# Epoch: 787 / 1000
# cost  0.088
# score  0.985
#
# Epoch: 788 / 1000
# cost  0.087
# score  0.985
#
# Epoch: 789 / 1000
# cost  0.087
# score  0.985
#
# Epoch: 790 / 1000
# cost  0.086
# score  0.985
#
# Epoch: 791 / 1000
# cost  0.086
# score  0.985
#
# Epoch: 792 / 1000
# cost  0.085
# score  0.985
#
# Epoch: 793 / 1000
# cost  0.085
# score  0.985
#
# Epoch: 794 / 1000
# cost  0.084
# score  0.985
#
# Epoch: 795 / 1000
# cost  0.084
# score  0.99
#
# Epoch: 796 / 1000
# cost  0.083
# score  0.99
#
# Epoch: 797 / 1000
# cost  0.083
# score  0.99
#
# Epoch: 798 / 1000
# cost  0.082
# score  0.99
#
# Epoch: 799 / 1000
# cost  0.082
# score  0.99
#
# Epoch: 800 / 1000
# cost  0.082
# score  0.99
#
# Epoch: 801 / 1000
# cost  0.081
# score  0.99
#
# Epoch: 802 / 1000
# cost  0.081
# score  0.99
#
# Epoch: 803 / 1000
# cost  0.08
# score  0.99
#
# Epoch: 804 / 1000
# cost  0.08
# score  0.99
#
# Epoch: 805 / 1000
# cost  0.079
# score  0.99
#
# Epoch: 806 / 1000
# cost  0.079
# score  0.99
#
# Epoch: 807 / 1000
# cost  0.079
# score  0.99
#
# Epoch: 808 / 1000
# cost  0.078
# score  0.99
#
# Epoch: 809 / 1000
# cost  0.078
# score  0.99
#
# Epoch: 810 / 1000
# cost  0.077
# score  0.99
#
# Epoch: 811 / 1000
# cost  0.077
# score  0.99
#
# Epoch: 812 / 1000
# cost  0.077
# score  0.99
#
# Epoch: 813 / 1000
# cost  0.076
# score  0.99
#
# Epoch: 814 / 1000
# cost  0.076
# score  0.99
#
# Epoch: 815 / 1000
# cost  0.075
# score  0.99
#
# Epoch: 816 / 1000
# cost  0.075
# score  0.99
#
# Epoch: 817 / 1000
# cost  0.075
# score  0.99
#
# Epoch: 818 / 1000
# cost  0.074
# score  0.99
#
# Epoch: 819 / 1000
# cost  0.074
# score  0.99
#
# Epoch: 820 / 1000
# cost  0.073
# score  0.99
#
# Epoch: 821 / 1000
# cost  0.073
# score  0.995
#
# Epoch: 822 / 1000
# cost  0.073
# score  0.995
#
# Epoch: 823 / 1000
# cost  0.072
# score  0.995
#
# Epoch: 824 / 1000
# cost  0.072
# score  0.995
#
# Epoch: 825 / 1000
# cost  0.072
# score  0.995
#
# Epoch: 826 / 1000
# cost  0.071
# score  0.995
#
# Epoch: 827 / 1000
# cost  0.071
# score  0.995
#
# Epoch: 828 / 1000
# cost  0.071
# score  0.995
#
# Epoch: 829 / 1000
# cost  0.07
# score  0.995
#
# Epoch: 830 / 1000
# cost  0.07
# score  0.995
#
# Epoch: 831 / 1000
# cost  0.069
# score  0.995
#
# Epoch: 832 / 1000
# cost  0.069
# score  0.995
#
# Epoch: 833 / 1000
# cost  0.069
# score  0.995
#
# Epoch: 834 / 1000
# cost  0.068
# score  0.995
#
# Epoch: 835 / 1000
# cost  0.068
# score  0.995
#
# Epoch: 836 / 1000
# cost  0.068
# score  0.995
#
# Epoch: 837 / 1000
# cost  0.067
# score  0.995
#
# Epoch: 838 / 1000
# cost  0.067
# score  0.995
#
# Epoch: 839 / 1000
# cost  0.067
# score  0.995
#
# Epoch: 840 / 1000
# cost  0.066
# score  0.995
#
# Epoch: 841 / 1000
# cost  0.066
# score  0.995
#
# Epoch: 842 / 1000
# cost  0.066
# score  0.995
#
# Epoch: 843 / 1000
# cost  0.066
# score  0.995
#
# Epoch: 844 / 1000
# cost  0.065
# score  0.995
#
# Epoch: 845 / 1000
# cost  0.065
# score  0.995
#
# Epoch: 846 / 1000
# cost  0.065
# score  0.995
#
# Epoch: 847 / 1000
# cost  0.064
# score  0.995
#
# Epoch: 848 / 1000
# cost  0.064
# score  0.995
#
# Epoch: 849 / 1000
# cost  0.064
# score  0.995
#
# Epoch: 850 / 1000
# cost  0.063
# score  0.995
#
# Epoch: 851 / 1000
# cost  0.063
# score  0.995
#
# Epoch: 852 / 1000
# cost  0.063
# score  0.995
#
# Epoch: 853 / 1000
# cost  0.063
# score  0.995
#
# Epoch: 854 / 1000
# cost  0.062
# score  0.995
#
# Epoch: 855 / 1000
# cost  0.062
# score  0.995
#
# Epoch: 856 / 1000
# cost  0.062
# score  0.995
#
# Epoch: 857 / 1000
# cost  0.061
# score  0.995
#
# Epoch: 858 / 1000
# cost  0.061
# score  0.995
#
# Epoch: 859 / 1000
# cost  0.061
# score  0.995
#
# Epoch: 860 / 1000
# cost  0.061
# score  0.995
#
# Epoch: 861 / 1000
# cost  0.06
# score  0.995
#
# Epoch: 862 / 1000
# cost  0.06
# score  0.995
#
# Epoch: 863 / 1000
# cost  0.06
# score  0.995
#
# Epoch: 864 / 1000
# cost  0.059
# score  0.995
#
# Epoch: 865 / 1000
# cost  0.059
# score  0.995
#
# Epoch: 866 / 1000
# cost  0.059
# score  0.995
#
# Epoch: 867 / 1000
# cost  0.059
# score  0.995
#
# Epoch: 868 / 1000
# cost  0.058
# score  0.995
#
# Epoch: 869 / 1000
# cost  0.058
# score  0.995
#
# Epoch: 870 / 1000
# cost  0.058
# score  0.995
#
# Epoch: 871 / 1000
# cost  0.058
# score  0.995
#
# Epoch: 872 / 1000
# cost  0.057
# score  0.995
#
# Epoch: 873 / 1000
# cost  0.057
# score  0.995
#
# Epoch: 874 / 1000
# cost  0.057
# score  0.995
#
# Epoch: 875 / 1000
# cost  0.057
# score  0.995
#
# Epoch: 876 / 1000
# cost  0.056
# score  0.995
#
# Epoch: 877 / 1000
# cost  0.056
# score  0.995
#
# Epoch: 878 / 1000
# cost  0.056
# score  0.995
#
# Epoch: 879 / 1000
# cost  0.056
# score  0.995
#
# Epoch: 880 / 1000
# cost  0.055
# score  0.995
#
# Epoch: 881 / 1000
# cost  0.055
# score  0.995
#
# Epoch: 882 / 1000
# cost  0.055
# score  0.995
#
# Epoch: 883 / 1000
# cost  0.055
# score  0.995
#
# Epoch: 884 / 1000
# cost  0.054
# score  0.995
#
# Epoch: 885 / 1000
# cost  0.054
# score  0.995
#
# Epoch: 886 / 1000
# cost  0.054
# score  0.995
#
# Epoch: 887 / 1000
# cost  0.054
# score  0.995
#
# Epoch: 888 / 1000
# cost  0.054
# score  0.995
#
# Epoch: 889 / 1000
# cost  0.053
# score  0.995
#
# Epoch: 890 / 1000
# cost  0.053
# score  0.995
#
# Epoch: 891 / 1000
# cost  0.053
# score  0.995
#
# Epoch: 892 / 1000
# cost  0.053
# score  0.995
#
# Epoch: 893 / 1000
# cost  0.052
# score  0.995
#
# Epoch: 894 / 1000
# cost  0.052
# score  0.995
#
# Epoch: 895 / 1000
# cost  0.052
# score  0.995
#
# Epoch: 896 / 1000
# cost  0.052
# score  0.995
#
# Epoch: 897 / 1000
# cost  0.052
# score  0.995
#
# Epoch: 898 / 1000
# cost  0.051
# score  0.995
#
# Epoch: 899 / 1000
# cost  0.051
# score  0.995
#
# Epoch: 900 / 1000
# cost  0.051
# score  0.995
#
# Epoch: 901 / 1000
# cost  0.051
# score  0.995
#
# Epoch: 902 / 1000
# cost  0.051
# score  0.995
#
# Epoch: 903 / 1000
# cost  0.05
# score  0.995
#
# Epoch: 904 / 1000
# cost  0.05
# score  0.995
#
# Epoch: 905 / 1000
# cost  0.05
# score  0.995
#
# Epoch: 906 / 1000
# cost  0.05
# score  0.995
#
# Epoch: 907 / 1000
# cost  0.05
# score  0.995
#
# Epoch: 908 / 1000
# cost  0.049
# score  0.995
#
# Epoch: 909 / 1000
# cost  0.049
# score  0.995
#
# Epoch: 910 / 1000
# cost  0.049
# score  0.995
#
# Epoch: 911 / 1000
# cost  0.049
# score  0.995
#
# Epoch: 912 / 1000
# cost  0.049
# score  0.995
#
# Epoch: 913 / 1000
# cost  0.048
# score  0.995
#
# Epoch: 914 / 1000
# cost  0.048
# score  0.995
#
# Epoch: 915 / 1000
# cost  0.048
# score  0.995
#
# Epoch: 916 / 1000
# cost  0.048
# score  0.995
#
# Epoch: 917 / 1000
# cost  0.048
# score  0.995
#
# Epoch: 918 / 1000
# cost  0.048
# score  0.995
#
# Epoch: 919 / 1000
# cost  0.047
# score  0.995
#
# Epoch: 920 / 1000
# cost  0.047
# score  0.995
#
# Epoch: 921 / 1000
# cost  0.047
# score  0.995
#
# Epoch: 922 / 1000
# cost  0.047
# score  0.995
#
# Epoch: 923 / 1000
# cost  0.047
# score  0.995
#
# Epoch: 924 / 1000
# cost  0.046
# score  0.995
#
# Epoch: 925 / 1000
# cost  0.046
# score  0.995
#
# Epoch: 926 / 1000
# cost  0.046
# score  0.995
#
# Epoch: 927 / 1000
# cost  0.046
# score  0.995
#
# Epoch: 928 / 1000
# cost  0.046
# score  0.995
#
# Epoch: 929 / 1000
# cost  0.046
# score  0.995
#
# Epoch: 930 / 1000
# cost  0.045
# score  0.995
#
# Epoch: 931 / 1000
# cost  0.045
# score  0.995
#
# Epoch: 932 / 1000
# cost  0.045
# score  0.995
#
# Epoch: 933 / 1000
# cost  0.045
# score  0.995
#
# Epoch: 934 / 1000
# cost  0.045
# score  0.995
#
# Epoch: 935 / 1000
# cost  0.045
# score  0.995
#
# Epoch: 936 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 937 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 938 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 939 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 940 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 941 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 942 / 1000
# cost  0.044
# score  0.995
#
# Epoch: 943 / 1000
# cost  0.043
# score  0.995
#
# Epoch: 944 / 1000
# cost  0.043
# score  0.995
#
# Epoch: 945 / 1000
# cost  0.043
# score  0.995
#
# Epoch: 946 / 1000
# cost  0.043
# score  0.995
#
# Epoch: 947 / 1000
# cost  0.043
# score  0.995
#
# Epoch: 948 / 1000
# cost  0.043
# score  0.995
#
# Epoch: 949 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 950 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 951 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 952 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 953 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 954 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 955 / 1000
# cost  0.042
# score  0.995
#
# Epoch: 956 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 957 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 958 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 959 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 960 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 961 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 962 / 1000
# cost  0.041
# score  0.995
#
# Epoch: 963 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 964 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 965 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 966 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 967 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 968 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 969 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 970 / 1000
# cost  0.04
# score  0.995
#
# Epoch: 971 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 972 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 973 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 974 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 975 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 976 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 977 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 978 / 1000
# cost  0.039
# score  0.995
#
# Epoch: 979 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 980 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 981 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 982 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 983 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 984 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 985 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 986 / 1000
# cost  0.038
# score  0.995
#
# Epoch: 987 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 988 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 989 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 990 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 991 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 992 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 993 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 994 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 995 / 1000
# cost  0.037
# score  0.995
#
# Epoch: 996 / 1000
# cost  0.036
# score  0.995
#
# Epoch: 997 / 1000
# cost  0.036
# score  0.995
#
# Epoch: 998 / 1000
# cost  0.036
# score  0.995
#
# Epoch: 999 / 1000
# cost  0.036
# score  0.995

# %%
plt.plot(Lerror, label="MSE")
plt.plot(Lscore, label="Score")
plt.legend()
plt.show()
