# %%
import sys 
sys.path.append('..')
from projet_etu import *
import numpy as np 
import matplotlib as plt 
from mltools import *
from utils import *
from loss import *
from activation import *

# %%
input_size = 2
hidden_size =16
output_size = 1
# Définir les données d'entraînement
X, Y = gen_arti(data_type=1)
Y = np.where(Y == -1, 0, Y)

# %%
linear1 = Linear(input_size, hidden_size)

tanh = TanH()
linear2 = Linear(hidden_size, output_size)
sigmoid = Sigmoid()
mse_loss = MSELoss()
ce_loss = CrossEntropyLoss()
loss_list = []

# %%
seq = Sequential([linear1, tanh, linear2, sigmoid])

# %%
Lerror, Lscore= SGD(seq, mse_loss, X, Y, predict= lambda x : np.round(seq.forward(x), 0).astype(int), eps=1e-3, max_iter= 500, batch_size= 10)
# Out:
# Epoch: 0 / 500
# Loss  0.259
# score  0.58
# Epoch: 1 / 500
# Loss  0.257
# score  0.59
# Epoch: 2 / 500
# Loss  0.255
# score  0.595
# Epoch: 3 / 500
# Loss  0.252
# score  0.6
# Epoch: 4 / 500
# Loss  0.25
# score  0.615
# Epoch: 5 / 500
# Loss  0.248
# score  0.62
# Epoch: 6 / 500
# Loss  0.246
# score  0.62
# Epoch: 7 / 500
# Loss  0.244
# score  0.625
# Epoch: 8 / 500
# Loss  0.242
# score  0.63
# Epoch: 9 / 500
# Loss  0.24
# score  0.635
# Epoch: 10 / 500
# Loss  0.238
# score  0.635
# Epoch: 11 / 500
# Loss  0.237
# score  0.64
# Epoch: 12 / 500
# Loss  0.235
# score  0.64
# Epoch: 13 / 500
# Loss  0.233
# score  0.645
# Epoch: 14 / 500
# Loss  0.232
# score  0.65
# Epoch: 15 / 500
# Loss  0.23
# score  0.65
# Epoch: 16 / 500
# Loss  0.228
# score  0.65
# Epoch: 17 / 500
# Loss  0.227
# score  0.66
# Epoch: 18 / 500
# Loss  0.225
# score  0.665
# Epoch: 19 / 500
# Loss  0.224
# score  0.665
# Epoch: 20 / 500
# Loss  0.222
# score  0.66
# Epoch: 21 / 500
# Loss  0.221
# score  0.66
# Epoch: 22 / 500
# Loss  0.219
# score  0.66
# Epoch: 23 / 500
# Loss  0.218
# score  0.67
# Epoch: 24 / 500
# Loss  0.217
# score  0.665
# Epoch: 25 / 500
# Loss  0.215
# score  0.665
# Epoch: 26 / 500
# Loss  0.214
# score  0.675
# Epoch: 27 / 500
# Loss  0.213
# score  0.675
# Epoch: 28 / 500
# Loss  0.212
# score  0.675
# Epoch: 29 / 500
# Loss  0.21
# score  0.675
# Epoch: 30 / 500
# Loss  0.209
# score  0.675
# Epoch: 31 / 500
# Loss  0.208
# score  0.68
# Epoch: 32 / 500
# Loss  0.207
# score  0.68
# Epoch: 33 / 500
# Loss  0.206
# score  0.68
# Epoch: 34 / 500
# Loss  0.205
# score  0.68
# Epoch: 35 / 500
# Loss  0.204
# score  0.68
# Epoch: 36 / 500
# Loss  0.202
# score  0.685
# Epoch: 37 / 500
# Loss  0.201
# score  0.685
# Epoch: 38 / 500
# Loss  0.2
# score  0.685
# Epoch: 39 / 500
# Loss  0.199
# score  0.685
# Epoch: 40 / 500
# Loss  0.198
# score  0.69
# Epoch: 41 / 500
# Loss  0.197
# score  0.69
# Epoch: 42 / 500
# Loss  0.196
# score  0.7
# Epoch: 43 / 500
# Loss  0.195
# score  0.71
# Epoch: 44 / 500
# Loss  0.194
# score  0.735
# Epoch: 45 / 500
# Loss  0.193
# score  0.74
# Epoch: 46 / 500
# Loss  0.192
# score  0.765
# Epoch: 47 / 500
# Loss  0.191
# score  0.79
# Epoch: 48 / 500
# Loss  0.191
# score  0.82
# Epoch: 49 / 500
# Loss  0.19
# score  0.845
# Epoch: 50 / 500
# Loss  0.189
# score  0.845
# Epoch: 51 / 500
# Loss  0.188
# score  0.855
# Epoch: 52 / 500
# Loss  0.187
# score  0.855
# Epoch: 53 / 500
# Loss  0.186
# score  0.875
# Epoch: 54 / 500
# Loss  0.185
# score  0.89
# Epoch: 55 / 500
# Loss  0.184
# score  0.885
# Epoch: 56 / 500
# Loss  0.183
# score  0.89
# Epoch: 57 / 500
# Loss  0.183
# score  0.895
# Epoch: 58 / 500
# Loss  0.182
# score  0.9
# Epoch: 59 / 500
# Loss  0.181
# score  0.905
# Epoch: 60 / 500
# Loss  0.18
# score  0.905
# Epoch: 61 / 500
# Loss  0.179
# score  0.905
# Epoch: 62 / 500
# Loss  0.178
# score  0.915
# Epoch: 63 / 500
# Loss  0.178
# score  0.92
# Epoch: 64 / 500
# Loss  0.177
# score  0.93
# Epoch: 65 / 500
# Loss  0.176
# score  0.93
# Epoch: 66 / 500
# Loss  0.175
# score  0.93
# Epoch: 67 / 500
# Loss  0.174
# score  0.94
# Epoch: 68 / 500
# Loss  0.174
# score  0.94
# Epoch: 69 / 500
# Loss  0.173
# score  0.94
# Epoch: 70 / 500
# Loss  0.172
# score  0.94
# Epoch: 71 / 500
# Loss  0.171
# score  0.945
# Epoch: 72 / 500
# Loss  0.17
# score  0.94
# Epoch: 73 / 500
# Loss  0.17
# score  0.94
# Epoch: 74 / 500
# Loss  0.169
# score  0.94
# Epoch: 75 / 500
# Loss  0.168
# score  0.94
# Epoch: 76 / 500
# Loss  0.167
# score  0.94
# Epoch: 77 / 500
# Loss  0.167
# score  0.94
# Epoch: 78 / 500
# Loss  0.166
# score  0.94
# Epoch: 79 / 500
# Loss  0.165
# score  0.94
# Epoch: 80 / 500
# Loss  0.164
# score  0.94
# Epoch: 81 / 500
# Loss  0.163
# score  0.94
# Epoch: 82 / 500
# Loss  0.163
# score  0.945
# Epoch: 83 / 500
# Loss  0.162
# score  0.945
# Epoch: 84 / 500
# Loss  0.161
# score  0.945
# Epoch: 85 / 500
# Loss  0.16
# score  0.945
# Epoch: 86 / 500
# Loss  0.16
# score  0.945
# Epoch: 87 / 500
# Loss  0.159
# score  0.945
# Epoch: 88 / 500
# Loss  0.158
# score  0.95
# Epoch: 89 / 500
# Loss  0.158
# score  0.95
# Epoch: 90 / 500
# Loss  0.157
# score  0.95
# Epoch: 91 / 500
# Loss  0.156
# score  0.95
# Epoch: 92 / 500
# Loss  0.155
# score  0.95
# Epoch: 93 / 500
# Loss  0.155
# score  0.95
# Epoch: 94 / 500
# Loss  0.154
# score  0.95
# Epoch: 95 / 500
# Loss  0.153
# score  0.95
# Epoch: 96 / 500
# Loss  0.152
# score  0.95
# Epoch: 97 / 500
# Loss  0.152
# score  0.95
# Epoch: 98 / 500
# Loss  0.151
# score  0.95
# Epoch: 99 / 500
# Loss  0.15
# score  0.95
# Epoch: 100 / 500
# Loss  0.15
# score  0.95
# Epoch: 101 / 500
# Loss  0.149
# score  0.95
# Epoch: 102 / 500
# Loss  0.148
# score  0.95
# Epoch: 103 / 500
# Loss  0.148
# score  0.96
# Epoch: 104 / 500
# Loss  0.147
# score  0.96
# Epoch: 105 / 500
# Loss  0.146
# score  0.96
# Epoch: 106 / 500
# Loss  0.145
# score  0.96
# Epoch: 107 / 500
# Loss  0.145
# score  0.96
# Epoch: 108 / 500
# Loss  0.144
# score  0.96
# Epoch: 109 / 500
# Loss  0.143
# score  0.96
# Epoch: 110 / 500
# Loss  0.143
# score  0.965
# Epoch: 111 / 500
# Loss  0.142
# score  0.965
# Epoch: 112 / 500
# Loss  0.141
# score  0.965
# Epoch: 113 / 500
# Loss  0.141
# score  0.965
# Epoch: 114 / 500
# Loss  0.14
# score  0.965
# Epoch: 115 / 500
# Loss  0.139
# score  0.965
# Epoch: 116 / 500
# Loss  0.139
# score  0.965
# Epoch: 117 / 500
# Loss  0.138
# score  0.965
# Epoch: 118 / 500
# Loss  0.137
# score  0.965
# Epoch: 119 / 500
# Loss  0.137
# score  0.965
# Epoch: 120 / 500
# Loss  0.136
# score  0.965
# Epoch: 121 / 500
# Loss  0.135
# score  0.965
# Epoch: 122 / 500
# Loss  0.135
# score  0.965
# Epoch: 123 / 500
# Loss  0.134
# score  0.965
# Epoch: 124 / 500
# Loss  0.133
# score  0.965
# Epoch: 125 / 500
# Loss  0.133
# score  0.965
# Epoch: 126 / 500
# Loss  0.132
# score  0.965
# Epoch: 127 / 500
# Loss  0.132
# score  0.965
# Epoch: 128 / 500
# Loss  0.131
# score  0.965
# Epoch: 129 / 500
# Loss  0.13
# score  0.965
# Epoch: 130 / 500
# Loss  0.13
# score  0.965
# Epoch: 131 / 500
# Loss  0.129
# score  0.965
# Epoch: 132 / 500
# Loss  0.128
# score  0.965
# Epoch: 133 / 500
# Loss  0.128
# score  0.965
# Epoch: 134 / 500
# Loss  0.127
# score  0.965
# Epoch: 135 / 500
# Loss  0.127
# score  0.965
# Epoch: 136 / 500
# Loss  0.126
# score  0.965
# Epoch: 137 / 500
# Loss  0.125
# score  0.965
# Epoch: 138 / 500
# Loss  0.125
# score  0.965
# Epoch: 139 / 500
# Loss  0.124
# score  0.965
# Epoch: 140 / 500
# Loss  0.123
# score  0.965
# Epoch: 141 / 500
# Loss  0.123
# score  0.965
# Epoch: 142 / 500
# Loss  0.122
# score  0.965
# Epoch: 143 / 500
# Loss  0.122
# score  0.965
# Epoch: 144 / 500
# Loss  0.121
# score  0.965
# Epoch: 145 / 500
# Loss  0.121
# score  0.965
# Epoch: 146 / 500
# Loss  0.12
# score  0.965
# Epoch: 147 / 500
# Loss  0.119
# score  0.965
# Epoch: 148 / 500
# Loss  0.119
# score  0.965
# Epoch: 149 / 500
# Loss  0.118
# score  0.965
# Epoch: 150 / 500
# Loss  0.118
# score  0.965
# Epoch: 151 / 500
# Loss  0.117
# score  0.965
# Epoch: 152 / 500
# Loss  0.116
# score  0.965
# Epoch: 153 / 500
# Loss  0.116
# score  0.965
# Epoch: 154 / 500
# Loss  0.115
# score  0.965
# Epoch: 155 / 500
# Loss  0.115
# score  0.965
# Epoch: 156 / 500
# Loss  0.114
# score  0.965
# Epoch: 157 / 500
# Loss  0.114
# score  0.965
# Epoch: 158 / 500
# Loss  0.113
# score  0.965
# Epoch: 159 / 500
# Loss  0.113
# score  0.965
# Epoch: 160 / 500
# Loss  0.112
# score  0.965
# Epoch: 161 / 500
# Loss  0.111
# score  0.965
# Epoch: 162 / 500
# Loss  0.111
# score  0.965
# Epoch: 163 / 500
# Loss  0.11
# score  0.965
# Epoch: 164 / 500
# Loss  0.11
# score  0.965
# Epoch: 165 / 500
# Loss  0.109
# score  0.965
# Epoch: 166 / 500
# Loss  0.109
# score  0.965
# Epoch: 167 / 500
# Loss  0.108
# score  0.965
# Epoch: 168 / 500
# Loss  0.108
# score  0.965
# Epoch: 169 / 500
# Loss  0.107
# score  0.965
# Epoch: 170 / 500
# Loss  0.107
# score  0.965
# Epoch: 171 / 500
# Loss  0.106
# score  0.965
# Epoch: 172 / 500
# Loss  0.106
# score  0.965
# Epoch: 173 / 500
# Loss  0.105
# score  0.965
# Epoch: 174 / 500
# Loss  0.105
# score  0.965
# Epoch: 175 / 500
# Loss  0.104
# score  0.965
# Epoch: 176 / 500
# Loss  0.104
# score  0.965
# Epoch: 177 / 500
# Loss  0.103
# score  0.965
# Epoch: 178 / 500
# Loss  0.103
# score  0.965
# Epoch: 179 / 500
# Loss  0.102
# score  0.97
# Epoch: 180 / 500
# Loss  0.102
# score  0.97
# Epoch: 181 / 500
# Loss  0.101
# score  0.97
# Epoch: 182 / 500
# Loss  0.101
# score  0.97
# Epoch: 183 / 500
# Loss  0.1
# score  0.97
# Epoch: 184 / 500
# Loss  0.1
# score  0.97
# Epoch: 185 / 500
# Loss  0.099
# score  0.97
# Epoch: 186 / 500
# Loss  0.099
# score  0.975
# Epoch: 187 / 500
# Loss  0.098
# score  0.975
# Epoch: 188 / 500
# Loss  0.098
# score  0.975
# Epoch: 189 / 500
# Loss  0.097
# score  0.975
# Epoch: 190 / 500
# Loss  0.097
# score  0.975
# Epoch: 191 / 500
# Loss  0.097
# score  0.975
# Epoch: 192 / 500
# Loss  0.096
# score  0.975
# Epoch: 193 / 500
# Loss  0.096
# score  0.975
# Epoch: 194 / 500
# Loss  0.095
# score  0.975
# Epoch: 195 / 500
# Loss  0.095
# score  0.975
# Epoch: 196 / 500
# Loss  0.094
# score  0.975
# Epoch: 197 / 500
# Loss  0.094
# score  0.975
# Epoch: 198 / 500
# Loss  0.093
# score  0.975
# Epoch: 199 / 500
# Loss  0.093
# score  0.975
# Epoch: 200 / 500
# Loss  0.092
# score  0.975
# Epoch: 201 / 500
# Loss  0.092
# score  0.975
# Epoch: 202 / 500
# Loss  0.092
# score  0.975
# Epoch: 203 / 500
# Loss  0.091
# score  0.975
# Epoch: 204 / 500
# Loss  0.091
# score  0.975
# Epoch: 205 / 500
# Loss  0.09
# score  0.975
# Epoch: 206 / 500
# Loss  0.09
# score  0.975
# Epoch: 207 / 500
# Loss  0.089
# score  0.975
# Epoch: 208 / 500
# Loss  0.089
# score  0.975
# Epoch: 209 / 500
# Loss  0.089
# score  0.975
# Epoch: 210 / 500
# Loss  0.088
# score  0.975
# Epoch: 211 / 500
# Loss  0.088
# score  0.975
# Epoch: 212 / 500
# Loss  0.087
# score  0.975
# Epoch: 213 / 500
# Loss  0.087
# score  0.975
# Epoch: 214 / 500
# Loss  0.087
# score  0.975
# Epoch: 215 / 500
# Loss  0.086
# score  0.975
# Epoch: 216 / 500
# Loss  0.086
# score  0.975
# Epoch: 217 / 500
# Loss  0.085
# score  0.975
# Epoch: 218 / 500
# Loss  0.085
# score  0.975
# Epoch: 219 / 500
# Loss  0.085
# score  0.975
# Epoch: 220 / 500
# Loss  0.084
# score  0.975
# Epoch: 221 / 500
# Loss  0.084
# score  0.975
# Epoch: 222 / 500
# Loss  0.084
# score  0.975
# Epoch: 223 / 500
# Loss  0.083
# score  0.975
# Epoch: 224 / 500
# Loss  0.083
# score  0.975
# Epoch: 225 / 500
# Loss  0.082
# score  0.975
# Epoch: 226 / 500
# Loss  0.082
# score  0.975
# Epoch: 227 / 500
# Loss  0.082
# score  0.975
# Epoch: 228 / 500
# Loss  0.081
# score  0.975
# Epoch: 229 / 500
# Loss  0.081
# score  0.975
# Epoch: 230 / 500
# Loss  0.081
# score  0.975
# Epoch: 231 / 500
# Loss  0.08
# score  0.975
# Epoch: 232 / 500
# Loss  0.08
# score  0.975
# Epoch: 233 / 500
# Loss  0.079
# score  0.975
# Epoch: 234 / 500
# Loss  0.079
# score  0.975
# Epoch: 235 / 500
# Loss  0.079
# score  0.975
# Epoch: 236 / 500
# Loss  0.078
# score  0.975
# Epoch: 237 / 500
# Loss  0.078
# score  0.975
# Epoch: 238 / 500
# Loss  0.078
# score  0.975
# Epoch: 239 / 500
# Loss  0.077
# score  0.975
# Epoch: 240 / 500
# Loss  0.077
# score  0.975
# Epoch: 241 / 500
# Loss  0.077
# score  0.975
# Epoch: 242 / 500
# Loss  0.076
# score  0.975
# Epoch: 243 / 500
# Loss  0.076
# score  0.975
# Epoch: 244 / 500
# Loss  0.076
# score  0.975
# Epoch: 245 / 500
# Loss  0.075
# score  0.975
# Epoch: 246 / 500
# Loss  0.075
# score  0.975
# Epoch: 247 / 500
# Loss  0.075
# score  0.975
# Epoch: 248 / 500
# Loss  0.074
# score  0.975
# Epoch: 249 / 500
# Loss  0.074
# score  0.975
# Epoch: 250 / 500
# Loss  0.074
# score  0.975
# Epoch: 251 / 500
# Loss  0.073
# score  0.975
# Epoch: 252 / 500
# Loss  0.073
# score  0.975
# Epoch: 253 / 500
# Loss  0.073
# score  0.975
# Epoch: 254 / 500
# Loss  0.072
# score  0.975
# Epoch: 255 / 500
# Loss  0.072
# score  0.975
# Epoch: 256 / 500
# Loss  0.072
# score  0.975
# Epoch: 257 / 500
# Loss  0.072
# score  0.975
# Epoch: 258 / 500
# Loss  0.071
# score  0.975
# Epoch: 259 / 500
# Loss  0.071
# score  0.975
# Epoch: 260 / 500
# Loss  0.071
# score  0.975
# Epoch: 261 / 500
# Loss  0.07
# score  0.975
# Epoch: 262 / 500
# Loss  0.07
# score  0.975
# Epoch: 263 / 500
# Loss  0.07
# score  0.975
# Epoch: 264 / 500
# Loss  0.069
# score  0.975
# Epoch: 265 / 500
# Loss  0.069
# score  0.975
# Epoch: 266 / 500
# Loss  0.069
# score  0.975
# Epoch: 267 / 500
# Loss  0.069
# score  0.975
# Epoch: 268 / 500
# Loss  0.068
# score  0.98
# Epoch: 269 / 500
# Loss  0.068
# score  0.98
# Epoch: 270 / 500
# Loss  0.068
# score  0.98
# Epoch: 271 / 500
# Loss  0.067
# score  0.98
# Epoch: 272 / 500
# Loss  0.067
# score  0.98
# Epoch: 273 / 500
# Loss  0.067
# score  0.98
# Epoch: 274 / 500
# Loss  0.067
# score  0.985
# Epoch: 275 / 500
# Loss  0.066
# score  0.985
# Epoch: 276 / 500
# Loss  0.066
# score  0.985
# Epoch: 277 / 500
# Loss  0.066
# score  0.985
# Epoch: 278 / 500
# Loss  0.066
# score  0.985
# Epoch: 279 / 500
# Loss  0.065
# score  0.985
# Epoch: 280 / 500
# Loss  0.065
# score  0.985
# Epoch: 281 / 500
# Loss  0.065
# score  0.985
# Epoch: 282 / 500
# Loss  0.064
# score  0.985
# Epoch: 283 / 500
# Loss  0.064
# score  0.985
# Epoch: 284 / 500
# Loss  0.064
# score  0.985
# Epoch: 285 / 500
# Loss  0.064
# score  0.985
# Epoch: 286 / 500
# Loss  0.063
# score  0.985
# Epoch: 287 / 500
# Loss  0.063
# score  0.985
# Epoch: 288 / 500
# Loss  0.063
# score  0.985
# Epoch: 289 / 500
# Loss  0.063
# score  0.985
# Epoch: 290 / 500
# Loss  0.062
# score  0.985
# Epoch: 291 / 500
# Loss  0.062
# score  0.985
# Epoch: 292 / 500
# Loss  0.062
# score  0.985
# Epoch: 293 / 500
# Loss  0.062
# score  0.985
# Epoch: 294 / 500
# Loss  0.061
# score  0.985
# Epoch: 295 / 500
# Loss  0.061
# score  0.985
# Epoch: 296 / 500
# Loss  0.061
# score  0.985
# Epoch: 297 / 500
# Loss  0.061
# score  0.985
# Epoch: 298 / 500
# Loss  0.06
# score  0.985
# Epoch: 299 / 500
# Loss  0.06
# score  0.985
# Epoch: 300 / 500
# Loss  0.06
# score  0.99
# Epoch: 301 / 500
# Loss  0.06
# score  0.99
# Epoch: 302 / 500
# Loss  0.06
# score  0.99
# Epoch: 303 / 500
# Loss  0.059
# score  0.99
# Epoch: 304 / 500
# Loss  0.059
# score  0.99
# Epoch: 305 / 500
# Loss  0.059
# score  0.99
# Epoch: 306 / 500
# Loss  0.059
# score  0.99
# Epoch: 307 / 500
# Loss  0.058
# score  0.99
# Epoch: 308 / 500
# Loss  0.058
# score  0.99
# Epoch: 309 / 500
# Loss  0.058
# score  0.99
# Epoch: 310 / 500
# Loss  0.058
# score  0.99
# Epoch: 311 / 500
# Loss  0.057
# score  0.99
# Epoch: 312 / 500
# Loss  0.057
# score  0.99
# Epoch: 313 / 500
# Loss  0.057
# score  0.99
# Epoch: 314 / 500
# Loss  0.057
# score  0.99
# Epoch: 315 / 500
# Loss  0.057
# score  0.99
# Epoch: 316 / 500
# Loss  0.056
# score  0.99
# Epoch: 317 / 500
# Loss  0.056
# score  0.99
# Epoch: 318 / 500
# Loss  0.056
# score  0.99
# Epoch: 319 / 500
# Loss  0.056
# score  0.99
# Epoch: 320 / 500
# Loss  0.056
# score  0.99
# Epoch: 321 / 500
# Loss  0.055
# score  0.99
# Epoch: 322 / 500
# Loss  0.055
# score  0.99
# Epoch: 323 / 500
# Loss  0.055
# score  0.99
# Epoch: 324 / 500
# Loss  0.055
# score  0.99
# Epoch: 325 / 500
# Loss  0.055
# score  0.99
# Epoch: 326 / 500
# Loss  0.054
# score  0.99
# Epoch: 327 / 500
# Loss  0.054
# score  0.99
# Epoch: 328 / 500
# Loss  0.054
# score  0.99
# Epoch: 329 / 500
# Loss  0.054
# score  0.99
# Epoch: 330 / 500
# Loss  0.054
# score  0.99
# Epoch: 331 / 500
# Loss  0.053
# score  0.99
# Epoch: 332 / 500
# Loss  0.053
# score  0.99
# Epoch: 333 / 500
# Loss  0.053
# score  0.99
# Epoch: 334 / 500
# Loss  0.053
# score  0.99
# Epoch: 335 / 500
# Loss  0.053
# score  0.99
# Epoch: 336 / 500
# Loss  0.052
# score  0.99
# Epoch: 337 / 500
# Loss  0.052
# score  0.99
# Epoch: 338 / 500
# Loss  0.052
# score  0.99
# Epoch: 339 / 500
# Loss  0.052
# score  0.99
# Epoch: 340 / 500
# Loss  0.052
# score  0.99
# Epoch: 341 / 500
# Loss  0.052
# score  0.99
# Epoch: 342 / 500
# Loss  0.051
# score  0.99
# Epoch: 343 / 500
# Loss  0.051
# score  0.99
# Epoch: 344 / 500
# Loss  0.051
# score  0.99
# Epoch: 345 / 500
# Loss  0.051
# score  0.99
# Epoch: 346 / 500
# Loss  0.051
# score  0.99
# Epoch: 347 / 500
# Loss  0.05
# score  0.99
# Epoch: 348 / 500
# Loss  0.05
# score  0.99
# Epoch: 349 / 500
# Loss  0.05
# score  0.99
# Epoch: 350 / 500
# Loss  0.05
# score  0.99
# Epoch: 351 / 500
# Loss  0.05
# score  0.99
# Epoch: 352 / 500
# Loss  0.05
# score  0.99
# Epoch: 353 / 500
# Loss  0.049
# score  0.99
# Epoch: 354 / 500
# Loss  0.049
# score  0.99
# Epoch: 355 / 500
# Loss  0.049
# score  0.99
# Epoch: 356 / 500
# Loss  0.049
# score  0.99
# Epoch: 357 / 500
# Loss  0.049
# score  0.99
# Epoch: 358 / 500
# Loss  0.049
# score  0.99
# Epoch: 359 / 500
# Loss  0.048
# score  0.99
# Epoch: 360 / 500
# Loss  0.048
# score  0.99
# Epoch: 361 / 500
# Loss  0.048
# score  0.99
# Epoch: 362 / 500
# Loss  0.048
# score  0.99
# Epoch: 363 / 500
# Loss  0.048
# score  0.99
# Epoch: 364 / 500
# Loss  0.048
# score  0.99
# Epoch: 365 / 500
# Loss  0.047
# score  0.99
# Epoch: 366 / 500
# Loss  0.047
# score  0.99
# Epoch: 367 / 500
# Loss  0.047
# score  0.99
# Epoch: 368 / 500
# Loss  0.047
# score  0.99
# Epoch: 369 / 500
# Loss  0.047
# score  0.99
# Epoch: 370 / 500
# Loss  0.047
# score  0.99
# Epoch: 371 / 500
# Loss  0.046
# score  0.99
# Epoch: 372 / 500
# Loss  0.046
# score  0.99
# Epoch: 373 / 500
# Loss  0.046
# score  0.99
# Epoch: 374 / 500
# Loss  0.046
# score  0.99
# Epoch: 375 / 500
# Loss  0.046
# score  0.99
# Epoch: 376 / 500
# Loss  0.046
# score  0.99
# Epoch: 377 / 500
# Loss  0.046
# score  0.99
# Epoch: 378 / 500
# Loss  0.045
# score  0.99
# Epoch: 379 / 500
# Loss  0.045
# score  0.99
# Epoch: 380 / 500
# Loss  0.045
# score  0.99
# Epoch: 381 / 500
# Loss  0.045
# score  0.99
# Epoch: 382 / 500
# Loss  0.045
# score  0.99
# Epoch: 383 / 500
# Loss  0.045
# score  0.99
# Epoch: 384 / 500
# Loss  0.045
# score  0.99
# Epoch: 385 / 500
# Loss  0.044
# score  0.99
# Epoch: 386 / 500
# Loss  0.044
# score  0.99
# Epoch: 387 / 500
# Loss  0.044
# score  0.99
# Epoch: 388 / 500
# Loss  0.044
# score  0.99
# Epoch: 389 / 500
# Loss  0.044
# score  0.99
# Epoch: 390 / 500
# Loss  0.044
# score  0.99
# Epoch: 391 / 500
# Loss  0.044
# score  0.99
# Epoch: 392 / 500
# Loss  0.043
# score  0.99
# Epoch: 393 / 500
# Loss  0.043
# score  0.99
# Epoch: 394 / 500
# Loss  0.043
# score  0.99
# Epoch: 395 / 500
# Loss  0.043
# score  0.99
# Epoch: 396 / 500
# Loss  0.043
# score  0.99
# Epoch: 397 / 500
# Loss  0.043
# score  0.99
# Epoch: 398 / 500
# Loss  0.043
# score  0.99
# Epoch: 399 / 500
# Loss  0.043
# score  0.99
# Epoch: 400 / 500
# Loss  0.042
# score  0.99
# Epoch: 401 / 500
# Loss  0.042
# score  0.99
# Epoch: 402 / 500
# Loss  0.042
# score  0.99
# Epoch: 403 / 500
# Loss  0.042
# score  0.99
# Epoch: 404 / 500
# Loss  0.042
# score  0.99
# Epoch: 405 / 500
# Loss  0.042
# score  0.99
# Epoch: 406 / 500
# Loss  0.042
# score  0.99
# Epoch: 407 / 500
# Loss  0.041
# score  0.99
# Epoch: 408 / 500
# Loss  0.041
# score  0.99
# Epoch: 409 / 500
# Loss  0.041
# score  0.99
# Epoch: 410 / 500
# Loss  0.041
# score  0.99
# Epoch: 411 / 500
# Loss  0.041
# score  0.99
# Epoch: 412 / 500
# Loss  0.041
# score  0.99
# Epoch: 413 / 500
# Loss  0.041
# score  0.99
# Epoch: 414 / 500
# Loss  0.041
# score  0.99
# Epoch: 415 / 500
# Loss  0.041
# score  0.99
# Epoch: 416 / 500
# Loss  0.04
# score  0.99
# Epoch: 417 / 500
# Loss  0.04
# score  0.99
# Epoch: 418 / 500
# Loss  0.04
# score  0.99
# Epoch: 419 / 500
# Loss  0.04
# score  0.99
# Epoch: 420 / 500
# Loss  0.04
# score  0.99
# Epoch: 421 / 500
# Loss  0.04
# score  0.99
# Epoch: 422 / 500
# Loss  0.04
# score  0.99
# Epoch: 423 / 500
# Loss  0.04
# score  0.99
# Epoch: 424 / 500
# Loss  0.039
# score  0.99
# Epoch: 425 / 500
# Loss  0.039
# score  0.99
# Epoch: 426 / 500
# Loss  0.039
# score  0.99
# Epoch: 427 / 500
# Loss  0.039
# score  0.99
# Epoch: 428 / 500
# Loss  0.039
# score  0.99
# Epoch: 429 / 500
# Loss  0.039
# score  0.99
# Epoch: 430 / 500
# Loss  0.039
# score  0.99
# Epoch: 431 / 500
# Loss  0.039
# score  0.99
# Epoch: 432 / 500
# Loss  0.039
# score  0.99
# Epoch: 433 / 500
# Loss  0.038
# score  0.99
# Epoch: 434 / 500
# Loss  0.038
# score  0.99
# Epoch: 435 / 500
# Loss  0.038
# score  0.99
# Epoch: 436 / 500
# Loss  0.038
# score  0.99
# Epoch: 437 / 500
# Loss  0.038
# score  0.99
# Epoch: 438 / 500
# Loss  0.038
# score  0.99
# Epoch: 439 / 500
# Loss  0.038
# score  0.99
# Epoch: 440 / 500
# Loss  0.038
# score  0.99
# Epoch: 441 / 500
# Loss  0.038
# score  0.99
# Epoch: 442 / 500
# Loss  0.038
# score  0.99
# Epoch: 443 / 500
# Loss  0.037
# score  0.99
# Epoch: 444 / 500
# Loss  0.037
# score  0.99
# Epoch: 445 / 500
# Loss  0.037
# score  0.99
# Epoch: 446 / 500
# Loss  0.037
# score  0.99
# Epoch: 447 / 500
# Loss  0.037
# score  0.99
# Epoch: 448 / 500
# Loss  0.037
# score  0.99
# Epoch: 449 / 500
# Loss  0.037
# score  0.99
# Epoch: 450 / 500
# Loss  0.037
# score  0.99
# Epoch: 451 / 500
# Loss  0.037
# score  0.99
# Epoch: 452 / 500
# Loss  0.036
# score  0.99
# Epoch: 453 / 500
# Loss  0.036
# score  0.99
# Epoch: 454 / 500
# Loss  0.036
# score  0.99
# Epoch: 455 / 500
# Loss  0.036
# score  0.99
# Epoch: 456 / 500
# Loss  0.036
# score  0.99
# Epoch: 457 / 500
# Loss  0.036
# score  0.99
# Epoch: 458 / 500
# Loss  0.036
# score  0.99
# Epoch: 459 / 500
# Loss  0.036
# score  0.99
# Epoch: 460 / 500
# Loss  0.036
# score  0.99
# Epoch: 461 / 500
# Loss  0.036
# score  0.99
# Epoch: 462 / 500
# Loss  0.036
# score  0.99
# Epoch: 463 / 500
# Loss  0.035
# score  0.99
# Epoch: 464 / 500
# Loss  0.035
# score  0.99
# Epoch: 465 / 500
# Loss  0.035
# score  0.99
# Epoch: 466 / 500
# Loss  0.035
# score  0.99
# Epoch: 467 / 500
# Loss  0.035
# score  0.99
# Epoch: 468 / 500
# Loss  0.035
# score  0.99
# Epoch: 469 / 500
# Loss  0.035
# score  0.99
# Epoch: 470 / 500
# Loss  0.035
# score  0.99
# Epoch: 471 / 500
# Loss  0.035
# score  0.99
# Epoch: 472 / 500
# Loss  0.035
# score  0.99
# Epoch: 473 / 500
# Loss  0.035
# score  0.99
# Epoch: 474 / 500
# Loss  0.034
# score  0.99
# Epoch: 475 / 500
# Loss  0.034
# score  0.99
# Epoch: 476 / 500
# Loss  0.034
# score  0.99
# Epoch: 477 / 500
# Loss  0.034
# score  0.99
# Epoch: 478 / 500
# Loss  0.034
# score  0.99
# Epoch: 479 / 500
# Loss  0.034
# score  0.99
# Epoch: 480 / 500
# Loss  0.034
# score  0.99
# Epoch: 481 / 500
# Loss  0.034
# score  0.99
# Epoch: 482 / 500
# Loss  0.034
# score  0.99
# Epoch: 483 / 500
# Loss  0.034
# score  0.99
# Epoch: 484 / 500
# Loss  0.034
# score  0.99
# Epoch: 485 / 500
# Loss  0.033
# score  0.99
# Epoch: 486 / 500
# Loss  0.033
# score  0.99
# Epoch: 487 / 500
# Loss  0.033
# score  0.99
# Epoch: 488 / 500
# Loss  0.033
# score  0.99
# Epoch: 489 / 500
# Loss  0.033
# score  0.99
# Epoch: 490 / 500
# Loss  0.033
# score  0.99
# Epoch: 491 / 500
# Loss  0.033
# score  0.99
# Epoch: 492 / 500
# Loss  0.033
# score  0.99
# Epoch: 493 / 500
# Loss  0.033
# score  0.99
# Epoch: 494 / 500
# Loss  0.033
# score  0.99
# Epoch: 495 / 500
# Loss  0.033
# score  0.99
# Epoch: 496 / 500
# Loss  0.033
# score  0.99
# Epoch: 497 / 500
# Loss  0.032
# score  0.99
# Epoch: 498 / 500
# Loss  0.032
# score  0.99
# Epoch: 499 / 500
# Loss  0.032
# score  0.99

# %%
plt.plot(Lerror, label="MSE")
plt.legend()
plt.show()

# %%
plt.plot(Lscore, label="score")
plt.legend()
plt.show()
