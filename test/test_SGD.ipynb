# %%
import sys 
sys.path.append('..')
from projet_etu import *
import numpy as np 
import matplotlib as plt 
from mltools import *
from utils import *
from loss import *
from activation import *

# %%
input_size = 2
hidden_size =16
output_size = 1
# Définir les données d'entraînement
X, Y = gen_arti(data_type=1)
Y = np.where(Y == -1, 0, Y)

# %%
linear1 = Linear(input_size, hidden_size)

tanh = TanH()
linear2 = Linear(hidden_size, output_size)
sigmoid = Sigmoid()
mse_loss = MSELoss()
ce_loss = CrossEntropyLoss()
loss_list = []

# %%
seq = Sequential([linear1, tanh, linear2, sigmoid])

# %%
Lerror, Lscore, L_score_train = SGD(seq, mse_loss, X, Y, predict= lambda x : np.round(seq.forward(x), 0).astype(int), eps=3e-3, max_iter= 500, batch_size= 10)
# Out:
# Epoch: 0 / 500
# cost  0.247
# score  0.515
#
# Epoch: 1 / 500
# cost  0.245
# score  0.53
#
# Epoch: 2 / 500
# cost  0.244
# score  0.56
#
# Epoch: 3 / 500
# cost  0.242
# score  0.595
#
# Epoch: 4 / 500
# cost  0.24
# score  0.62
#
# Epoch: 5 / 500
# cost  0.239
# score  0.625
#
# Epoch: 6 / 500
# cost  0.238
# score  0.645
#
# Epoch: 7 / 500
# cost  0.236
# score  0.65
#
# Epoch: 8 / 500
# cost  0.235
# score  0.66
#
# Epoch: 9 / 500
# cost  0.234
# score  0.66
#
# Epoch: 10 / 500
# cost  0.232
# score  0.705
#
# Epoch: 11 / 500
# cost  0.231
# score  0.755
#
# Epoch: 12 / 500
# cost  0.23
# score  0.78
#
# Epoch: 13 / 500
# cost  0.229
# score  0.775
#
# Epoch: 14 / 500
# cost  0.228
# score  0.785
#
# Epoch: 15 / 500
# cost  0.227
# score  0.78
#
# Epoch: 16 / 500
# cost  0.225
# score  0.79
#
# Epoch: 17 / 500
# cost  0.224
# score  0.8
#
# Epoch: 18 / 500
# cost  0.223
# score  0.79
#
# Epoch: 19 / 500
# cost  0.222
# score  0.79
#
# Epoch: 20 / 500
# cost  0.221
# ...

# %%
plt.plot(Lerror, label="MSE")
plt.legend()
plt.show()

# %%
plt.plot(Lscore, label="score_test")
plt.plot(L_score_train, label="score_train")
plt.legend()
plt.show()
